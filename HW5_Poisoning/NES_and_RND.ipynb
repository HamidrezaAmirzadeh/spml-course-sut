# %% [markdown]
# # Hamidreza Amirzadeh
# ## 401206999
# ### Note: This work was done under collaboration with Ali Abdollahi

# %% [markdown]
# # **Preface**
# In this notebook you are going to implement a powerful blackbox attack namely [NES](https://arxiv.org/pdf/1804.08598.pdf) and test it on a regular target model, then you will use a simple but powerful defense called  Random Noise Defense ([RND](https://arxiv.org/pdf/2104.11470.pdf)) against this attack on the same target model in order to check the power of the aforementioned attack in the presence of this so-called defense.
# You will have to use a **CIFAR10 ResNet18 model** as the target model for this set of experiments.
# You may want to train a new model or load an already trained model, your choice, but this model must have at least 94% accuracy on CIFAR10 test set as told in the previous exercises.
#
# P.S. Don't normalize the data used for training.

# %%
from google.colab import drive
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch import Tensor
from typing import Type
import numpy as np
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from torch.autograd import Variable
from torch.utils.data import TensorDataset, DataLoader


device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
if device == 'cuda':
  print(torch.cuda.get_device_name(0))

drive.mount('/content/drive')
# %cd /content/drive/MyDrive/

from resnet import *

batch_size = 128
transform = transforms.Compose([transforms.RandomCrop(32, padding=4), transforms.RandomHorizontalFlip(), transforms.ToTensor(),])

trainset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/myCIFAR10', train = True, download = True, transform = transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size = batch_size, shuffle = True, num_workers = 2)

testset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/myCIFAR10', train = False, download = True, transform = transforms.Compose([transforms.ToTensor(),]))
testloader = torch.utils.data.DataLoader(testset, batch_size = batch_size, shuffle = False, num_workers = 2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# cuda
# Tesla T4
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
model = ResNet18()
model = model.to(device)

# %%
# load model
model_name = "resnet18_cifar10_model_hw5.pth"
CIFAR10_model_PATH = "/content/drive/MyDrive/" + model_name
state_dict = torch.load(CIFAR10_model_PATH)
model.load_state_dict(state_dict)

# %%
# init to train model
learning_rate = 0.01
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9 , weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=300)

# %%
epochs = 100
for epoch in range(epochs):
    model.train()
    print("epoch " + str(epoch))
    running_loss = 0.0

    for i, data in enumerate(trainloader, 0):

        inputs, labels = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        if i % 2000 == 1:
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss:.3f}')
            running_loss = 0.0
    if scheduler:
        scheduler.step()
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print(f'Standard Accuracy of ResNet18 model on the 10000 test images: {100 * correct / total} %')



print('Finished Training')
# Out:
# epoch 0
# [1,     2] loss: 4.704
# Standard Accuracy of ResNet18 model on the 10000 test images: 53.16 %
# epoch 1
# [2,     2] loss: 1.880
# Standard Accuracy of ResNet18 model on the 10000 test images: 68.94 %
# epoch 2
# [3,     2] loss: 1.578
# Standard Accuracy of ResNet18 model on the 10000 test images: 72.71 %
# epoch 3
# [4,     2] loss: 1.244
# Standard Accuracy of ResNet18 model on the 10000 test images: 69.43 %
# epoch 4
# [5,     2] loss: 1.070
# Standard Accuracy of ResNet18 model on the 10000 test images: 80.93 %
# epoch 5
# [6,     2] loss: 0.987
# Standard Accuracy of ResNet18 model on the 10000 test images: 78.96 %
# epoch 6
# [7,     2] loss: 0.966
# Standard Accuracy of ResNet18 model on the 10000 test images: 81.97 %
# epoch 7
# [8,     2] loss: 0.992
# Standard Accuracy of ResNet18 model on the 10000 test images: 80.36 %
# epoch 8
# [9,     2] loss: 0.593
# Standard Accuracy of ResNet18 model on the 10000 test images: 83.77 %
# epoch 9
# [10,     2] loss: 0.697
# Standard Accuracy of ResNet18 model on the 10000 test images: 80.55 %
# epoch 10
# [11,     2] loss: 0.751
# Standard Accuracy of ResNet18 model on the 10000 test images: 82.85 %
# epoch 11
# [12,     2] loss: 0.502
# Standard Accuracy of ResNet18 model on the 10000 test images: 80.48 %
# epoch 12
# [13,     2] loss: 0.528
# Standard Accuracy of ResNet18 model on the 10000 test images: 84.8 %
# epoch 13
# [14,     2] loss: 0.700
# Standard Accuracy of ResNet18 model on the 10000 test images: 86.32 %
# epoch 14
# [15,     2] loss: 0.449
# Standard Accuracy of ResNet18 model on the 10000 test images: 85.59 %
# epoch 15
# [16,     2] loss: 0.333
# Standard Accuracy of ResNet18 model on the 10000 test images: 87.33 %
# epoch 16
# [17,     2] loss: 0.332
# Standard Accuracy of ResNet18 model on the 10000 test images: 85.27 %
# epoch 17
# [18,     2] loss: 0.385
# Standard Accuracy of ResNet18 model on the 10000 test images: 87.93 %
# epoch 18
# [19,     2] loss: 0.392
# Standard Accuracy of ResNet18 model on the 10000 test images: 88.14 %
# epoch 19
# [20,     2] loss: 0.412
# Standard Accuracy of ResNet18 model on the 10000 test images: 86.52 %
# epoch 20
# [21,     2] loss: 0.267
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.2 %
# epoch 21
# [22,     2] loss: 0.324
# Standard Accuracy of ResNet18 model on the 10000 test images: 86.58 %
# epoch 22
# [23,     2] loss: 0.296
# Standard Accuracy of ResNet18 model on the 10000 test images: 85.17 %
# epoch 23
# [24,     2] loss: 0.283
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.85 %
# epoch 24
# [25,     2] loss: 0.329
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.65 %
# epoch 25
# [26,     2] loss: 0.237
# Standard Accuracy of ResNet18 model on the 10000 test images: 88.16 %
# epoch 26
# [27,     2] loss: 0.177
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.17 %
# epoch 27
# [28,     2] loss: 0.149
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.32 %
# epoch 28
# [29,     2] loss: 0.231
# Standard Accuracy of ResNet18 model on the 10000 test images: 88.99 %
# epoch 29
# [30,     2] loss: 0.215
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.14 %
# epoch 30
# [31,     2] loss: 0.175
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.89 %
# epoch 31
# [32,     2] loss: 0.201
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.12 %
# epoch 32
# [33,     2] loss: 0.210
# Standard Accuracy of ResNet18 model on the 10000 test images: 88.45 %
# epoch 33
# [34,     2] loss: 0.278
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.21 %
# epoch 34
# [35,     2] loss: 0.109
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.93 %
# epoch 35
# [36,     2] loss: 0.178
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.84 %
# epoch 36
# [37,     2] loss: 0.219
# Standard Accuracy of ResNet18 model on the 10000 test images: 88.24 %
# epoch 37
# [38,     2] loss: 0.222
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.75 %
# epoch 38
# [39,     2] loss: 0.240
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.22 %
# epoch 39
# [40,     2] loss: 0.168
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.41 %
# epoch 40
# [41,     2] loss: 0.124
# Standard Accuracy of ResNet18 model on the 10000 test images: 88.78 %
# epoch 41
# [42,     2] loss: 0.152
# Standard Accuracy of ResNet18 model on the 10000 test images: 88.48 %
# epoch 42
# [43,     2] loss: 0.139
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.48 %
# epoch 43
# [44,     2] loss: 0.134
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.61 %
# epoch 44
# [45,     2] loss: 0.103
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.45 %
# epoch 45
# [46,     2] loss: 0.106
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.23 %
# epoch 46
# [47,     2] loss: 0.054
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.05 %
# epoch 47
# [48,     2] loss: 0.136
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.62 %
# epoch 48
# [49,     2] loss: 0.170
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.78 %
# epoch 49
# [50,     2] loss: 0.064
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.7 %
# epoch 50
# [51,     2] loss: 0.115
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.59 %
# epoch 51
# [52,     2] loss: 0.079
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.04 %
# epoch 52
# [53,     2] loss: 0.121
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.52 %
# epoch 53
# [54,     2] loss: 0.169
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.91 %
# epoch 54
# [55,     2] loss: 0.120
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.34 %
# epoch 55
# [56,     2] loss: 0.066
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.7 %
# epoch 56
# [57,     2] loss: 0.069
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.96 %
# epoch 57
# [58,     2] loss: 0.068
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.83 %
# epoch 58
# [59,     2] loss: 0.173
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.79 %
# epoch 59
# [60,     2] loss: 0.113
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.67 %
# epoch 60
# [61,     2] loss: 0.100
# Standard Accuracy of ResNet18 model on the 10000 test images: 88.34 %
# epoch 61
# [62,     2] loss: 0.101
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.68 %
# epoch 62
# [63,     2] loss: 0.067
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.35 %
# epoch 63
# [64,     2] loss: 0.153
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.98 %
# epoch 64
# [65,     2] loss: 0.062
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.94 %
# epoch 65
# [66,     2] loss: 0.097
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.76 %
# epoch 66
# [67,     2] loss: 0.047
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.0 %
# epoch 67
# [68,     2] loss: 0.062
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.12 %
# epoch 68
# [69,     2] loss: 0.036
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.98 %
# epoch 69
# [70,     2] loss: 0.025
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.93 %
# epoch 70
# [71,     2] loss: 0.084
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.88 %
# epoch 71
# [72,     2] loss: 0.045
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.31 %
# epoch 72
# [73,     2] loss: 0.078
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.75 %
# epoch 73
# [74,     2] loss: 0.058
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.38 %
# epoch 74
# [75,     2] loss: 0.073
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.18 %
# epoch 75
# [76,     2] loss: 0.065
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.88 %
# epoch 76
# [77,     2] loss: 0.077
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.62 %
# epoch 77
# [78,     2] loss: 0.091
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.77 %
# epoch 78
# [79,     2] loss: 0.105
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.76 %
# epoch 79
# [80,     2] loss: 0.108
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.5 %
# epoch 80
# [81,     2] loss: 0.080
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.3 %
# epoch 81
# [82,     2] loss: 0.087
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.09 %
# epoch 82
# [83,     2] loss: 0.041
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.16 %
# epoch 83
# [84,     2] loss: 0.043
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.76 %
# epoch 84
# [85,     2] loss: 0.068
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.17 %
# epoch 85
# [86,     2] loss: 0.040
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.9 %
# epoch 86
# [87,     2] loss: 0.111
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.0 %
# epoch 87
# [88,     2] loss: 0.095
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.03 %
# epoch 88
# [89,     2] loss: 0.065
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.66 %
# epoch 89
# [90,     2] loss: 0.149
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.77 %
# epoch 90
# [91,     2] loss: 0.072
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.97 %
# epoch 91
# [92,     2] loss: 0.046
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.17 %
# epoch 92
# [93,     2] loss: 0.115
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.47 %
# epoch 93
# [94,     2] loss: 0.085
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.87 %
# epoch 94
# [95,     2] loss: 0.049
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.77 %
# epoch 95
# [96,     2] loss: 0.094
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.78 %
# epoch 96
# [97,     2] loss: 0.086
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.31 %
# epoch 97
# [98,     2] loss: 0.130
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.43 %
# epoch 98
# [99,     2] loss: 0.081
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.22 %
# epoch 99
# [100,     2] loss: 0.111
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.56 %
# Finished Training

# %%
epochs = 100
for epoch in range(epochs):
    model.train()
    print("epoch " + str(epoch))
    running_loss = 0.0

    for i, data in enumerate(trainloader, 0):

        inputs, labels = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1:    # print every 2000 mini-batches #1999
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss:.3f}')
            running_loss = 0.0
    if scheduler:
        scheduler.step()
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print(f'Standard Accuracy of ResNet18 model on the 10000 test images: {100 * correct / total} %')



print('Finished Training')
# Out:
# epoch 0
# [1,     2] loss: 0.044
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.48 %
# epoch 1
# [2,     2] loss: 0.048
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.14 %
# epoch 2
# [3,     2] loss: 0.071
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.95 %
# epoch 3
# [4,     2] loss: 0.043
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.95 %
# epoch 4
# [5,     2] loss: 0.042
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.39 %
# epoch 5
# [6,     2] loss: 0.056
# Standard Accuracy of ResNet18 model on the 10000 test images: 89.7 %
# epoch 6
# [7,     2] loss: 0.097
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.22 %
# epoch 7
# [8,     2] loss: 0.031
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.26 %
# epoch 8
# [9,     2] loss: 0.113
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.99 %
# epoch 9
# [10,     2] loss: 0.089
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.87 %
# epoch 10
# [11,     2] loss: 0.037
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.59 %
# epoch 11
# [12,     2] loss: 0.025
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.97 %
# epoch 12
# [13,     2] loss: 0.071
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.5 %
# epoch 13
# [14,     2] loss: 0.057
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.99 %
# epoch 14
# [15,     2] loss: 0.045
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.74 %
# epoch 15
# [16,     2] loss: 0.098
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.27 %
# epoch 16
# [17,     2] loss: 0.069
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.02 %
# epoch 17
# [18,     2] loss: 0.033
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.87 %
# epoch 18
# [19,     2] loss: 0.088
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.71 %
# epoch 19
# [20,     2] loss: 0.071
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.77 %
# epoch 20
# [21,     2] loss: 0.052
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.51 %
# epoch 21
# [22,     2] loss: 0.047
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.85 %
# epoch 22
# [23,     2] loss: 0.038
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.54 %
# epoch 23
# [24,     2] loss: 0.044
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.0 %
# epoch 24
# [25,     2] loss: 0.049
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.83 %
# epoch 25
# [26,     2] loss: 0.029
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.7 %
# epoch 26
# [27,     2] loss: 0.035
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.7 %
# epoch 27
# [28,     2] loss: 0.063
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.21 %
# epoch 28
# [29,     2] loss: 0.028
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.29 %
# epoch 29
# [30,     2] loss: 0.039
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.56 %
# epoch 30
# [31,     2] loss: 0.034
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.74 %
# epoch 31
# [32,     2] loss: 0.014
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.3 %
# epoch 32
# [33,     2] loss: 0.014
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.1 %
# epoch 33
# [34,     2] loss: 0.049
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.64 %
# epoch 34
# [35,     2] loss: 0.035
# Standard Accuracy of ResNet18 model on the 10000 test images: 90.95 %
# epoch 35
# [36,     2] loss: 0.066
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.27 %
# epoch 36
# [37,     2] loss: 0.039
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.1 %
# epoch 37
# [38,     2] loss: 0.048
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.02 %
# epoch 38
# [39,     2] loss: 0.023
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.31 %
# epoch 39
# [40,     2] loss: 0.042
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.18 %
# epoch 40
# [41,     2] loss: 0.040
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.11 %
# epoch 41
# [42,     2] loss: 0.049
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.96 %
# epoch 42
# [43,     2] loss: 0.022
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.8 %
# epoch 43
# [44,     2] loss: 0.054
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.45 %
# epoch 44
# [45,     2] loss: 0.018
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.85 %
# epoch 45
# [46,     2] loss: 0.022
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.48 %
# epoch 46
# [47,     2] loss: 0.020
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.17 %
# epoch 47
# [48,     2] loss: 0.027
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.91 %
# epoch 48
# [49,     2] loss: 0.066
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.8 %
# epoch 49
# [50,     2] loss: 0.050
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.78 %
# epoch 50
# [51,     2] loss: 0.107
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.43 %
# epoch 51
# [52,     2] loss: 0.011
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.68 %
# epoch 52
# [53,     2] loss: 0.020
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.83 %
# epoch 53
# [54,     2] loss: 0.029
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.33 %
# epoch 54
# [55,     2] loss: 0.030
# Standard Accuracy of ResNet18 model on the 10000 test images: 91.91 %
# epoch 55
# [56,     2] loss: 0.020
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.63 %
# epoch 56
# [57,     2] loss: 0.052
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.44 %
# epoch 57
# [58,     2] loss: 0.034
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.6 %
# epoch 58
# [59,     2] loss: 0.067
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.39 %
# epoch 59
# [60,     2] loss: 0.063
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.8 %
# epoch 60
# [61,     2] loss: 0.013
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.51 %
# epoch 61
# [62,     2] loss: 0.027
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.14 %
# epoch 62
# [63,     2] loss: 0.022
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.64 %
# epoch 63
# [64,     2] loss: 0.023
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.45 %
# epoch 64
# [65,     2] loss: 0.050
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.61 %
# epoch 65
# [66,     2] loss: 0.075
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.12 %
# epoch 66
# [67,     2] loss: 0.005
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.16 %
# epoch 67
# [68,     2] loss: 0.004
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.87 %
# epoch 68
# [69,     2] loss: 0.018
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.08 %
# epoch 69
# [70,     2] loss: 0.011
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.6 %
# epoch 70
# [71,     2] loss: 0.017
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.31 %
# epoch 71
# [72,     2] loss: 0.015
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.94 %
# epoch 72
# [73,     2] loss: 0.023
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.21 %
# epoch 73
# [74,     2] loss: 0.007
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.74 %
# epoch 74
# [75,     2] loss: 0.007
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.8 %
# epoch 75
# [76,     2] loss: 0.002
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.46 %
# epoch 76
# [77,     2] loss: 0.004
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.25 %
# epoch 77
# [78,     2] loss: 0.030
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.52 %
# epoch 78
# [79,     2] loss: 0.016
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.45 %
# epoch 79
# [80,     2] loss: 0.012
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.17 %
# epoch 80
# [81,     2] loss: 0.012
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.98 %
# epoch 81
# [82,     2] loss: 0.006
# Standard Accuracy of ResNet18 model on the 10000 test images: 92.23 %
# epoch 82
# [83,     2] loss: 0.012
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.68 %
# epoch 83
# [84,     2] loss: 0.006
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.56 %
# epoch 84
# [85,     2] loss: 0.009
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.41 %
# epoch 85
# [86,     2] loss: 0.025
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.54 %
# epoch 86
# [87,     2] loss: 0.008
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.92 %
# epoch 87
# [88,     2] loss: 0.007
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.75 %
# epoch 88
# [89,     2] loss: 0.003
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.89 %
# epoch 89
# [90,     2] loss: 0.003
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.92 %
# epoch 90
# [91,     2] loss: 0.004
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.75 %
# epoch 91
# [92,     2] loss: 0.013
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.82 %
# epoch 92
# [93,     2] loss: 0.004
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.74 %
# epoch 93
# [94,     2] loss: 0.006
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.79 %
# epoch 94
# [95,     2] loss: 0.003
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.81 %
# epoch 95
# [96,     2] loss: 0.003
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.94 %
# epoch 96
# [97,     2] loss: 0.002
# Standard Accuracy of ResNet18 model on the 10000 test images: 94.4 %
# epoch 97
# [98,     2] loss: 0.002
# Standard Accuracy of ResNet18 model on the 10000 test images: 93.83 %
# epoch 98
# [99,     2] loss: 0.004
# Standard Accuracy of ResNet18 model on the 10000 test images: 94.15 %
# epoch 99
# [100,     2] loss: 0.002
# Standard Accuracy of ResNet18 model on the 10000 test images: 94.29 %
# Finished Training

# %%
# save model
model.eval()
model_name = "resnet18_cifar10_model_hw5.pth"
CIFAR10_model_PATH = "/content/drive/MyDrive/" + model_name
torch.save(model.state_dict(), CIFAR10_model_PATH)

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for data in testloader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Standard Accuracy of ResNet18 model on the 10000 test images: {100 * correct / total} %')
# Out:
# Standard Accuracy of ResNet18 model on the 10000 test images: 94.86 %

# %% [markdown]
# # **Natural Evolutionary Strategies (NES)**
#
# Firstly complete the code for the attack itself and then the add_Gaussian method used for the Random Noise Defense in the NES attack class.

# %%
import torch
import numpy as np
import torch as ch
import torchvision
import torchvision.transforms.functional as F
import torchvision.transforms as transforms
import argparse
import json
import pdb
import os
import time
import math
from torchvision import models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torch.nn import DataParallel
from torch.nn.modules import Upsample
from matplotlib import pyplot as plt

CLASSIFIERS = {
    "resnet18": (models.resnet50, 224),
}

NUM_CLASSES = {
    "cifar10": 10,
}

# Set the path to your dataset
CIFAR10_PATH = "/content/drive/MyDrive/myCIFAR10"

if CIFAR10_PATH == "":
  raise ValueError("Please fill out the path to Cifar10!")

class NES():

  def __init__(self, model_to_fool, args, dataset_size, RND_coefficient, device):


      if args != None:
        self.args = args
      else:
        self.max_queries = 10000
        self.fd_eta = 0.01
        self.image_lr = 0.01
        self.mode = "linf"
        self.json_config = None
        self.epsilon = 0.05
        self.batch_size = 10
        self.log_process = "store_true"
        self.gradient_iters = 15
        self.total_images = 10000
        self.classifier = 'resnet18'
        self.args = {'max_queries': self.max_queries,
          'fd_eta': self.fd_eta,
          'image_lr': self.image_lr,
          'mode': self.mode,
          'json_config': self.json_config,
          'epsilon': self.epsilon,
          'batch_size': self.batch_size,
          'log_progress': self.log_progress,
          'gradient_iters': self.gradient_iters,
          'total_images': self.total_images,
          'classifier': self.classifier,
          }
      self.model_to_fool = model_to_fool
      self.dataset_size = dataset_size
      self.RND_coefficient = RND_coefficient
      self.device = device
      if self.device == 'cuda':
        ch.set_default_tensor_type('torch.cuda.FloatTensor')
      else:
        ch.set_default_tensor_type('torch.FloatTensor')

      if self.dataset_size == 32:
        self.channel_size = 3
      else:
        raise ValueError("Please check out the dataset_size parameter...")


  """For setting up the Random Noise Defense"""

  def add_Gausian(self, input_image, coeff):
    # Firstly define a random epsilon with the input image shape
    # Remember that it should be a float
    # Add the epsilon with the proper coefficient to the input image
    # Don't forget to clamp it between the right values
    # P.S. Remember to convert everything to the right device
    #############################
    # Your code goes here
    epsilon = ch.randn_like(input_image)
    return torch.clamp(input_image + coeff*epsilon, 0, 1)
    #############################


  def generate(self):
      dataset = None
      if self.dataset_size == 32:
        transform = transforms.Compose([transforms.ToTensor(), transforms.Resize(self.dataset_size), transforms.CenterCrop(self.dataset_size),])
        dataset = torchvision.datasets.CIFAR10(root = CIFAR10_PATH, train = False, download = False, transform = transform)
      else:
        raise ValueError("Please check out the dataset_size parameter...")

      dataset_loader = DataLoader(dataset, batch_size=self.args["batch_size"])
      total_correct, total_adv, total_queries = 0, 0, 0
      for i, (images, targets) in enumerate(dataset_loader):
          if i*self.args["batch_size"] >= self.args["total_images"]:
              break

          res = self.make_adversarial_examples(images.to(self.device), targets.to(self.device), self.args, self.model_to_fool, self.dataset_size)
          ncc = res['num_correctly_classified'] # Number of correctly classified images (originally)
          num_adv = ncc * res['success_rate'] # Success rate was calculated as (# adv)/(# correct classified)
          queries = num_adv * res['average_queries'] # Average queries was calculated as (total queries for advs)/(# advs)
          total_correct += ncc
          total_adv += num_adv
          total_queries += queries
          print("i: " + str(i))
          sucRate = res['success_rate']
          print(f'success_rate : {sucRate}')
          print(f'number of Adversarials : {int(num_adv)}')
          print(f'number of queries : {int(queries)}')

      print("-"*80)
      if total_adv != 0:
        print("Final Success Rate: {succ} | Final Average Queries for Successful Adv Examples: {aq}".format(
                aq=int(total_queries/total_adv),
                succ=total_adv/total_correct))
      else:
        """If total adversarial examples is zero then we won't print any avg number of queries for success
        because we had no success and the avg number of queries has exceeded the budget"""
        print("Final Success Rate: {succ} ".format(
                # aq = total_queries,
                succ=total_adv/total_correct))
      print("-"*80)
      return


  def norm(self, t):
      assert len(t.shape) == 4
      norm_vec = ch.sqrt(t.pow(2).sum(dim=[1,2,3])).view(-1, 1, 1, 1)
      norm_vec += (norm_vec == 0).float()*1e-8
      return norm_vec

  ###
  # Different optimization steps
  # All take the form of func(x, g, lr)
  # eg: exponentiated gradients
  # gd: gradient descent
  # l2/linf: projected gradient descent
  ###


  def eg_step(self, x, g, lr):
      real_x = (x + 1)/2 # from [-1, 1] to [0, 1]
      pos = real_x*ch.exp(lr*g)
      neg = (1-real_x)*ch.exp(-lr*g)
      new_x = pos/(pos+neg)
      return new_x*2-1

  def linf_step(self, x, g, lr):
      return x + lr*ch.sign(g)

  def l2_prior_step(self, x, g, lr):
      new_x = x + lr*g/self.norm(g)
      norm_new_x = self.norm(new_x)
      norm_mask = (norm_new_x < 1.0).float()
      return new_x*norm_mask + (1-norm_mask)*new_x/norm_new_x

  def gd_prior_step(self, x, g, lr):
      return x + lr*g

  def l2_image_step(self, x, g, lr):
      return x + lr*g/self.norm(g)

  ##
  # Projection steps for l2 and linf constraints:
  # All take the form of func(new_x, old_x, epsilon)
  ##

  def l2_proj(self, image, eps):
      orig = image.clone()
      def proj(new_x):
          delta = new_x - orig
          out_of_bounds_mask = (self.norm(delta) > eps).float()
          x = (orig + eps*delta/self.norm(delta))*out_of_bounds_mask
          x += new_x*(1-out_of_bounds_mask)
          return x
      return proj

  def linf_proj(self, image, eps):
      orig = image.clone()
      def proj(new_x):
          return orig + ch.clamp(new_x - orig, -eps, eps)
      return proj

  ##
  # Main functions
  ##

  def make_adversarial_examples(self, image, true_label, args, model_to_fool, DATASET_SIZE):
      '''
      The main process for generating adversarial examples with priors.
      '''
      # Initial setup
      prior_size = DATASET_SIZE
      upsampler = Upsample(size=(DATASET_SIZE, DATASET_SIZE))
      total_queries = ch.zeros(args["batch_size"])
      prior = ch.zeros(args["batch_size"], self.channel_size, prior_size, prior_size)
      dim = prior.nelement()/args["batch_size"]
      image_step = self.l2_image_step if args["mode"] == 'l2' else self.linf_step
      proj_maker = self.l2_proj if args["mode"] == 'l2' else self.linf_proj
      proj_step = proj_maker(image, args["epsilon"])

      # Loss function
      criterion = ch.nn.CrossEntropyLoss(reduction='none')

      def normalized_eval(x):
          x_copy = x.clone()

          # You can comment or uncomment the code needed for a specific case
          """################## Normal prediction ##################"""
          x_copy = ch.clamp(x_copy, 0, 1)
          return self.model_to_fool(x_copy)

          """################## Prediction using random noise defense ##################"""
          x_copy_noisy = self.add_Gausian(x_copy, self.RND_coefficient)
          x_copy_noisy = ch.clamp(x_copy_noisy, 0, 1)
          return self.model_to_fool(x_copy_noisy)

      L = lambda x: criterion(normalized_eval(x), true_label)

      losses = L(image)

      # Original classifications
      orig_images = image.clone()

      # You can comment or uncomment the code needed for a specific case
      """##################Normal prediction##################"""
      orig_classes = self.model_to_fool(orig_images).argmax(1).to(self.device)

      """################## Prediction using random noise defense ##################"""
      image_noisy = self.add_Gausian(image, self.RND_coefficient)
      image_noisy = ch.clamp(image_noisy, 0, 1)
      orig_classes = self.model_to_fool(image_noisy).argmax(1).to(self.device)

      correct_classified_mask = (orig_classes == true_label).float()
      total_ims = correct_classified_mask.sum()
      not_dones_mask = correct_classified_mask.clone()

      t = 0
      while not ch.any(total_queries > args["max_queries"]):
          t += args["gradient_iters"]*2
          if t >= args["max_queries"]:
              break

          prior = ch.zeros_like(image)
          for _ in range(args["gradient_iters"]):

              # Define a tensor of random Gaussian noise with the input image shape
              # Then devide this tensor by (dim**0.5)
              # Now add and subtract the defined noise with the fd_eta coefficient with the original image
              # Finally build the gradient estimation of the loss using the finite difference method
              #############################
              # Your code goes here
              exp_noise = ch.randn_like(image)/(dim**0.5)
              est_deriv = (L(image + args['fd_eta']*exp_noise) - L(image - args['fd_eta']*exp_noise))/args['fd_eta']
              #############################

              prior += est_deriv.view(-1, 1, 1, 1)*exp_noise

          # Preserve images that are already done,
          # Unless we are specifically measuring gradient estimation
          prior = prior*not_dones_mask.view(-1, 1, 1, 1)

          ## Update the image:
          # take a pgd step using the prior
          new_im = image_step(image, upsampler(prior*correct_classified_mask.view(-1, 1, 1, 1)), args["image_lr"])
          image = proj_step(new_im)
          image = ch.clamp(image, 0, 1)

          if args["mode"] == 'l2':
              if not ch.all(self.norm(image - orig_images) <= args["epsilon"] + 1e-3):
                  pass
                  # pdb.set_trace()
          else:
              if not (image - orig_images).max() <= args["epsilon"] + 1e-3:
                pass
                  # pdb.set_trace()

          ## Continue query count
          total_queries += 2*args["gradient_iters"]*not_dones_mask
          not_dones_mask = not_dones_mask*((normalized_eval(image).argmax(1) == true_label).float())

          ## Logging and stuff

          # new_losses = L(image)
          success_mask = (1 - not_dones_mask)*correct_classified_mask
          num_success = success_mask.sum()
          if num_success != 0:
            success_queries = ((success_mask*total_queries).sum()/num_success).cpu().item()
          else:
            success_queries = ((success_mask*total_queries).sum()).cpu().item()
          """If num_success == 0 it means that the number of successful adv examples was zero (No adv examples could be made!)
          so success queries must not be printed """

          current_success_rate = (num_success/correct_classified_mask.sum()).cpu().item()
          #not_done_loss = ((new_losses*not_dones_mask).sum()/not_dones_mask.sum()).cpu().item()
          max_curr_queries = total_queries.max().cpu().item()
          # if args["log_progress"]:
          #   print("Queries: %d (%d) | Success rate: %f | Average queries: %f" % (max_curr_queries , t, current_success_rate, success_queries))

          if current_success_rate == 1.0:
              break

      return {
              'average_queries': success_queries,
              'num_correctly_classified': correct_classified_mask.sum().cpu().item(),
              'success_rate': current_success_rate,
              'images_orig': orig_images.cpu().numpy(),
              'images_adv': image.cpu().numpy(),
              'all_queries': total_queries.cpu().numpy(),
              'correctly_classified': correct_classified_mask.cpu().numpy(),
              'success': success_mask.cpu().numpy()
      }

# %% [markdown]
# # **Attack Arguments Setup**
#
# **Write a report and indicate the success rate and average number of qureies for sections A and B.**
#
# A) Now you must launch the attack using different values;
# For the whole CIFAR10 test set, first on the regular target model and without the Random Noise Defense, with fd_eta parameter of 0.01 and 0.001, using "linf" mode (2 results).
#
# B) Then apply the Random Noise Defense on the target model with RND_coefficient of 0.01 and 0.02 against NES with fd_eta parameter of 0.01 and 0.001 again using the "linf" mode (4 results).
#
# Analyse and compare the results of both sections in your report.

# %%
budget = 1000
target_model_arch = 'resnet18'
dataset_size = 32

args = {'max_queries': budget,
              'fd_eta': 0.01,
              'image_lr': 0.01,
              'mode': 'linf',
              'json_config': None,
              'epsilon': 0.05,
              'batch_size': 100,
              'log_progress': "store_true",
              'gradient_iters': 15,
              'total_images': 10000,
              'classifier': target_model_arch,
              }
"""
RND_coefficient = ?
device = ?
target_model.eval()
"""
print('without defense :')

with torch.no_grad():
    # Launch the attack using the NES class and its generate method
    #############################
    # Your code goes here
    nes = NES(model_to_fool = model, dataset_size = dataset_size, args = args, device = device, RND_coefficient=0)
    model.eval()
    for fd_eta in [0.01, 0.001]:
      print(f'fd_eta = {fd_eta}')
      args['fd_eta'] = fd_eta
      _ = nes.generate()

    #############################
# Out:
# without defense :
# fd_eta = 0.01
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# i: 0
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 22679
# i: 1
# success_rate : 0.957446813583374
# numAdv : 90
# queries : 24210
# i: 2
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 21779
# i: 3
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 21539
# i: 4
# success_rate : 0.9684210419654846
# numAdv : 91
# queries : 23459
# i: 5
# success_rate : 0.9175257682800293
# numAdv : 88
# queries : 27600
# i: 6
# success_rate : 0.9375
# numAdv : 90
# queries : 23520
# i: 7
# success_rate : 0.9677419066429138
# numAdv : 89
# queries : 22709
# i: 8
# success_rate : 0.9347826242446899
# numAdv : 86
# queries : 25500
# i: 9
# success_rate : 0.8297872543334961
# numAdv : 78
# queries : 19320
# i: 10
# success_rate : 0.936170220375061
# numAdv : 88
# queries : 21780
# i: 11
# success_rate : 0.914893627166748
# numAdv : 86
# queries : 22470
# i: 12
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 24869
# i: 13
# success_rate : 0.8958333134651184
# numAdv : 85
# queries : 23189
# i: 14
# success_rate : 0.8969072103500366
# numAdv : 86
# queries : 23309
# i: 15
# success_rate : 0.9368420839309692
# numAdv : 88
# queries : 21689
# i: 16
# success_rate : 0.9375
# numAdv : 90
# queries : 26310
# i: 17
# success_rate : 0.9042553305625916
# numAdv : 85
# queries : 24480
# i: 18
# success_rate : 0.936170220375061
# numAdv : 88
# queries : 24599
# i: 19
# success_rate : 0.9263157844543457
# numAdv : 87
# queries : 24929
# i: 20
# success_rate : 0.936170220375061
# numAdv : 88
# queries : 21389
# i: 21
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 24840
# i: 22
# success_rate : 0.932584285736084
# numAdv : 83
# queries : 23250
# i: 23
# success_rate : 0.9473684430122375
# numAdv : 90
# queries : 25740
# i: 24
# success_rate : 0.8947368264198303
# numAdv : 84
# queries : 20999
# i: 25
# success_rate : 0.9670329689979553
# numAdv : 88
# queries : 20640
# i: 26
# success_rate : 0.9175257682800293
# numAdv : 88
# queries : 23579
# i: 27
# success_rate : 0.978723406791687
# numAdv : 92
# queries : 27659
# i: 28
# success_rate : 0.9255319237709045
# numAdv : 87
# queries : 24779
# i: 29
# success_rate : 0.9479166865348816
# numAdv : 91
# queries : 22140
# i: 30
# success_rate : 0.8541666865348816
# numAdv : 82
# queries : 20760
# i: 31
# success_rate : 0.8865979313850403
# numAdv : 85
# queries : 22740
# i: 32
# success_rate : 0.9583333134651184
# numAdv : 91
# queries : 24810
# i: 33
# success_rate : 0.945652186870575
# numAdv : 87
# queries : 21869
# i: 34
# success_rate : 0.9247311949729919
# numAdv : 86
# queries : 23760
# i: 35
# success_rate : 0.9368420839309692
# numAdv : 88
# queries : 26939
# i: 36
# success_rate : 0.8924731016159058
# numAdv : 82
# queries : 20490
# i: 37
# success_rate : 0.9230769276618958
# numAdv : 84
# queries : 24269
# i: 38
# success_rate : 0.96875
# numAdv : 93
# queries : 27210
# i: 39
# success_rate : 0.9278350472450256
# numAdv : 89
# queries : 22740
# i: 40
# success_rate : 0.9255319237709045
# numAdv : 87
# queries : 22559
# i: 41
# success_rate : 0.9139785170555115
# numAdv : 85
# queries : 23159
# i: 42
# success_rate : 0.9052631855010986
# numAdv : 86
# queries : 25110
# i: 43
# success_rate : 0.9375
# numAdv : 90
# queries : 28470
# i: 44
# success_rate : 0.9175257682800293
# numAdv : 88
# queries : 23429
# i: 45
# success_rate : 0.8947368264198303
# numAdv : 84
# queries : 18059
# i: 46
# success_rate : 0.8736842274665833
# numAdv : 83
# queries : 19230
# i: 47
# success_rate : 0.8936170339584351
# numAdv : 84
# queries : 25769
# i: 48
# success_rate : 0.8888888955116272
# numAdv : 88
# queries : 21300
# i: 49
# success_rate : 0.95652174949646
# numAdv : 88
# queries : 20099
# i: 50
# success_rate : 0.9090909361839294
# numAdv : 90
# queries : 22140
# i: 51
# success_rate : 0.9263157844543457
# numAdv : 87
# queries : 21719
# i: 52
# success_rate : 0.9468085169792175
# numAdv : 89
# queries : 22380
# i: 53
# success_rate : 0.907216489315033
# numAdv : 87
# queries : 22199
# i: 54
# success_rate : 0.9375
# numAdv : 90
# queries : 24420
# i: 55
# success_rate : 0.9375
# numAdv : 90
# queries : 22439
# i: 56
# success_rate : 0.9042553305625916
# numAdv : 85
# queries : 22469
# i: 57
# success_rate : 0.90625
# numAdv : 87
# queries : 24810
# i: 58
# success_rate : 0.9239130616188049
# numAdv : 85
# queries : 20460
# i: 59
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 22290
# i: 60
# success_rate : 0.9111111164093018
# numAdv : 82
# queries : 20729
# i: 61
# success_rate : 0.914893627166748
# numAdv : 86
# queries : 22289
# i: 62
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 22530
# i: 63
# success_rate : 0.9100000262260437
# numAdv : 91
# queries : 24060
# i: 64
# success_rate : 0.9255319237709045
# numAdv : 87
# queries : 20520
# i: 65
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 22019
# i: 66
# success_rate : 0.9578947424888611
# numAdv : 91
# queries : 24779
# i: 67
# success_rate : 0.9450549483299255
# numAdv : 86
# queries : 23250
# i: 68
# success_rate : 0.9479166865348816
# numAdv : 91
# queries : 20160
# i: 69
# success_rate : 0.9375
# numAdv : 90
# queries : 23909
# i: 70
# success_rate : 0.9354838728904724
# numAdv : 87
# queries : 26850
# i: 71
# success_rate : 0.9793814420700073
# numAdv : 94
# queries : 23310
# i: 72
# success_rate : 0.9583333134651184
# numAdv : 91
# queries : 25890
# i: 73
# success_rate : 0.96875
# numAdv : 93
# queries : 26249
# i: 74
# success_rate : 0.9368420839309692
# numAdv : 88
# queries : 24240
# i: 75
# success_rate : 0.8602150678634644
# numAdv : 80
# queries : 23310
# i: 76
# success_rate : 0.9462365508079529
# numAdv : 87
# queries : 21330
# i: 77
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 24359
# i: 78
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 22979
# i: 79
# success_rate : 0.9578947424888611
# numAdv : 91
# queries : 26220
# i: 80
# success_rate : 0.938144326210022
# numAdv : 90
# queries : 23639
# i: 81
# success_rate : 0.9473684430122375
# numAdv : 90
# queries : 22740
# i: 82
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 25140
# i: 83
# success_rate : 0.9583333134651184
# numAdv : 91
# queries : 21780
# i: 84
# success_rate : 0.932584285736084
# numAdv : 83
# queries : 23399
# i: 85
# success_rate : 0.901098906993866
# numAdv : 82
# queries : 23099
# i: 86
# success_rate : 0.9578947424888611
# numAdv : 91
# queries : 25020
# i: 87
# success_rate : 0.9021739363670349
# numAdv : 83
# queries : 20640
# i: 88
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 22710
# i: 89
# success_rate : 0.938144326210022
# numAdv : 90
# queries : 22409
# i: 90
# success_rate : 0.9578947424888611
# numAdv : 91
# queries : 25799
# i: 91
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 26670
# i: 92
# success_rate : 0.9354838728904724
# numAdv : 87
# queries : 21990
# i: 93
# success_rate : 0.945652186870575
# numAdv : 87
# queries : 24270
# i: 94
# success_rate : 0.9587628841400146
# numAdv : 92
# queries : 23430
# i: 95
# success_rate : 0.90625
# numAdv : 87
# queries : 23009
# i: 96
# success_rate : 0.9081632494926453
# numAdv : 88
# queries : 23579
# i: 97
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 23490
# i: 98
# success_rate : 0.9354838728904724
# numAdv : 87
# queries : 21569
# i: 99
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 21539
# --------------------------------------------------------------------------------
# Final Success Rate: 0.9270503927629355 | Final Average Queries for Successful Adv Examples: 264
# --------------------------------------------------------------------------------
# fd_eta = 0.001
# i: 0
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 23100
# i: 1
# success_rate : 0.936170220375061
# numAdv : 88
# queries : 21930
# i: 2
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 22379
# i: 3
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 23010
# i: 4
# success_rate : 0.9263157844543457
# numAdv : 87
# queries : 21480
# i: 5
# success_rate : 0.938144326210022
# numAdv : 90
# queries : 29400
# i: 6
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 23279
# i: 7
# success_rate : 0.9677419066429138
# numAdv : 89
# queries : 22979
# i: 8
# success_rate : 0.9021739363670349
# numAdv : 83
# queries : 22230
# i: 9
# success_rate : 0.8510638475418091
# numAdv : 80
# queries : 22260
# i: 10
# success_rate : 0.9042553305625916
# numAdv : 85
# queries : 20339
# i: 11
# success_rate : 0.9255319237709045
# numAdv : 87
# queries : 24360
# i: 12
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 24329
# i: 13
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 26879
# i: 14
# success_rate : 0.907216489315033
# numAdv : 87
# queries : 24840
# i: 15
# success_rate : 0.9263157844543457
# numAdv : 87
# queries : 20579
# i: 16
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 24360
# i: 17
# success_rate : 0.914893627166748
# numAdv : 86
# queries : 23640
# i: 18
# success_rate : 0.9042553305625916
# numAdv : 85
# queries : 22590
# i: 19
# success_rate : 0.8736842274665833
# numAdv : 83
# queries : 20760
# i: 20
# success_rate : 0.936170220375061
# numAdv : 88
# queries : 20879
# i: 21
# success_rate : 0.8958333134651184
# numAdv : 85
# queries : 23579
# i: 22
# success_rate : 0.8876404762268066
# numAdv : 79
# queries : 19290
# i: 23
# success_rate : 0.9473684430122375
# numAdv : 90
# queries : 25470
# i: 24
# success_rate : 0.9052631855010986
# numAdv : 86
# queries : 22140
# i: 25
# success_rate : 0.9450549483299255
# numAdv : 86
# queries : 19379
# i: 26
# success_rate : 0.938144326210022
# numAdv : 90
# queries : 25799
# i: 27
# success_rate : 0.9468085169792175
# numAdv : 89
# queries : 26310
# i: 28
# success_rate : 0.9255319237709045
# numAdv : 87
# queries : 24150
# i: 29
# success_rate : 0.9583333134651184
# numAdv : 91
# queries : 23279
# i: 30
# success_rate : 0.8645833134651184
# numAdv : 82
# queries : 22109
# i: 31
# success_rate : 0.8969072103500366
# numAdv : 86
# queries : 23399
# i: 32
# success_rate : 0.96875
# numAdv : 93
# queries : 25769
# i: 33
# success_rate : 0.945652186870575
# numAdv : 87
# queries : 21660
# i: 34
# success_rate : 0.9032257795333862
# numAdv : 83
# queries : 22379
# i: 35
# success_rate : 0.9157894849777222
# numAdv : 87
# queries : 24810
# i: 36
# success_rate : 0.9032257795333862
# numAdv : 83
# queries : 20429
# i: 37
# success_rate : 0.9230769276618958
# numAdv : 84
# queries : 24390
# i: 38
# success_rate : 0.9479166865348816
# numAdv : 91
# queries : 27150
# i: 39
# success_rate : 0.907216489315033
# numAdv : 87
# queries : 21990
# i: 40
# success_rate : 0.9042553305625916
# numAdv : 85
# queries : 20609
# i: 41
# success_rate : 0.9032257795333862
# numAdv : 83
# queries : 23190
# i: 42
# success_rate : 0.8947368264198303
# numAdv : 84
# queries : 24240
# i: 43
# success_rate : 0.8645833134651184
# numAdv : 82
# queries : 23340
# i: 44
# success_rate : 0.9484536051750183
# numAdv : 91
# queries : 27180
# i: 45
# success_rate : 0.9157894849777222
# numAdv : 87
# queries : 19439
# i: 46
# success_rate : 0.8631578683853149
# numAdv : 81
# queries : 18599
# i: 47
# success_rate : 0.8510638475418091
# numAdv : 80
# queries : 22920
# i: 48
# success_rate : 0.8888888955116272
# numAdv : 88
# queries : 21719
# i: 49
# success_rate : 0.945652186870575
# numAdv : 87
# queries : 20609
# i: 50
# success_rate : 0.9090909361839294
# numAdv : 90
# queries : 21540
# i: 51
# success_rate : 0.9368420839309692
# numAdv : 88
# queries : 23789
# i: 52
# success_rate : 0.9255319237709045
# numAdv : 87
# queries : 21959
# i: 53
# success_rate : 0.9175257682800293
# numAdv : 88
# queries : 24569
# i: 54
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 23880
# i: 55
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 22290
# i: 56
# success_rate : 0.957446813583374
# numAdv : 90
# queries : 24449
# i: 57
# success_rate : 0.8958333134651184
# numAdv : 85
# queries : 23039
# i: 58
# success_rate : 0.9130434989929199
# numAdv : 84
# queries : 21240
# i: 59
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 22619
# i: 60
# success_rate : 0.8888888955116272
# numAdv : 80
# queries : 19290
# i: 61
# success_rate : 0.9042553305625916
# numAdv : 85
# queries : 23640
# i: 62
# success_rate : 0.9375
# numAdv : 90
# queries : 25560
# i: 63
# success_rate : 0.8999999761581421
# numAdv : 89
# queries : 24960
# i: 64
# success_rate : 0.9042553305625916
# numAdv : 85
# queries : 20400
# i: 65
# success_rate : 0.9375
# numAdv : 90
# queries : 24899
# i: 66
# success_rate : 0.9578947424888611
# numAdv : 91
# queries : 25049
# i: 67
# success_rate : 0.9340659379959106
# numAdv : 85
# queries : 24209
# i: 68
# success_rate : 0.9375
# numAdv : 90
# queries : 20729
# i: 69
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 21990
# i: 70
# success_rate : 0.9247311949729919
# numAdv : 86
# queries : 26940
# i: 71
# success_rate : 0.969072163105011
# numAdv : 93
# queries : 23550
# i: 72
# success_rate : 0.9583333134651184
# numAdv : 91
# queries : 25799
# i: 73
# success_rate : 0.9583333134651184
# numAdv : 91
# queries : 26369
# i: 74
# success_rate : 0.9157894849777222
# numAdv : 87
# queries : 23039
# i: 75
# success_rate : 0.8602150678634644
# numAdv : 80
# queries : 24780
# i: 76
# success_rate : 0.9784946441650391
# numAdv : 91
# queries : 24390
# i: 77
# success_rate : 0.90625
# numAdv : 87
# queries : 23250
# i: 78
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 24119
# i: 79
# success_rate : 0.9578947424888611
# numAdv : 91
# queries : 26519
# i: 80
# success_rate : 0.9484536051750183
# numAdv : 91
# queries : 25110
# i: 81
# success_rate : 0.9368420839309692
# numAdv : 88
# queries : 22559
# i: 82
# success_rate : 0.9583333134651184
# numAdv : 91
# queries : 27299
# i: 83
# success_rate : 0.96875
# numAdv : 93
# queries : 25260
# i: 84
# success_rate : 0.9213483333587646
# numAdv : 82
# queries : 22889
# i: 85
# success_rate : 0.901098906993866
# numAdv : 82
# queries : 25229
# i: 86
# success_rate : 0.9368420839309692
# numAdv : 88
# queries : 23189
# i: 87
# success_rate : 0.9130434989929199
# numAdv : 84
# queries : 21630
# i: 88
# success_rate : 0.8958333134651184
# numAdv : 85
# queries : 21569
# i: 89
# success_rate : 0.938144326210022
# numAdv : 90
# queries : 24420
# i: 90
# success_rate : 0.9684210419654846
# numAdv : 91
# queries : 26340
# i: 91
# success_rate : 0.9166666865348816
# numAdv : 88
# queries : 26550
# i: 92
# success_rate : 0.9569892287254333
# numAdv : 88
# queries : 24150
# i: 93
# success_rate : 0.9239130616188049
# numAdv : 85
# queries : 23970
# i: 94
# success_rate : 0.9484536051750183
# numAdv : 91
# queries : 22140
# i: 95
# success_rate : 0.90625
# numAdv : 87
# queries : 22710
# i: 96
# success_rate : 0.8877550959587097
# numAdv : 86
# queries : 24659
# i: 97
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 25019
# i: 98
# success_rate : 0.9677419066429138
# numAdv : 89
# queries : 23999
# i: 99
# success_rate : 0.9270833134651184
# numAdv : 88
# queries : 22739
# --------------------------------------------------------------------------------
# Final Success Rate: 0.9222011383251377 | Final Average Queries for Successful Adv Examples: 267
# --------------------------------------------------------------------------------

# %%
print('defence with RND_coefficient = 0.01 :')

with torch.no_grad():
    # Launch the attack using the NES class and its generate method
    #############################
    # Your code goes here
    nes = NES(model_to_fool = model, dataset_size = dataset_size, args = args, device = device, RND_coefficient=0.01)
    model.eval()
    for fd_eta in [0.01, 0.001]:
      print(f'fd_eta = {fd_eta}')
      args['fd_eta'] = fd_eta
      _ = nes.generate()

    #############################
# Out:
# defence with RND_coefficient = 0.01 :
# fd_eta = 0.01
# i: 0
# success_rate : 0.27173912525177
# numAdv : 24
# queries : 11759
# i: 1
# success_rate : 0.301075279712677
# numAdv : 28
# queries : 9510
# i: 2
# success_rate : 0.2886597812175751
# numAdv : 27
# queries : 11609
# i: 3
# success_rate : 0.24742268025875092
# numAdv : 23
# queries : 6779
# i: 4
# success_rate : 0.28421053290367126
# numAdv : 27
# queries : 9960
# i: 5
# success_rate : 0.1875
# numAdv : 18
# queries : 7020
# i: 6
# success_rate : 0.25
# numAdv : 24
# queries : 7980
# i: 7
# success_rate : 0.29347825050354004
# numAdv : 26
# queries : 5789
# i: 8
# success_rate : 0.24468085169792175
# numAdv : 23
# queries : 7769
# i: 9
# success_rate : 0.17391304671764374
# numAdv : 16
# queries : 3390
# i: 10
# success_rate : 0.34736841917037964
# numAdv : 32
# queries : 10080
# i: 11
# success_rate : 0.23404255509376526
# numAdv : 22
# queries : 7079
# i: 12
# success_rate : 0.2210526317358017
# numAdv : 21
# queries : 6690
# i: 13
# success_rate : 0.1979166716337204
# numAdv : 19
# queries : 5100
# i: 14
# success_rate : 0.16326530277729034
# numAdv : 15
# queries : 5459
# i: 15
# success_rate : 0.2395833283662796
# numAdv : 22
# queries : 7470
# i: 16
# success_rate : 0.2291666716337204
# numAdv : 22
# queries : 6690
# i: 17
# success_rate : 0.1894736886024475
# numAdv : 18
# queries : 6210
# i: 18
# success_rate : 0.24468085169792175
# numAdv : 23
# queries : 6569
# i: 19
# success_rate : 0.1808510571718216
# numAdv : 16
# queries : 5789
# i: 20
# success_rate : 0.3076923191547394
# numAdv : 28
# queries : 7410
# i: 21
# success_rate : 0.25
# numAdv : 24
# queries : 7560
# i: 22
# success_rate : 0.2584269642829895
# numAdv : 22
# queries : 7319
# i: 23
# success_rate : 0.16842105984687805
# numAdv : 16
# queries : 4830
# i: 24
# success_rate : 0.28723403811454773
# numAdv : 26
# queries : 9089
# i: 25
# success_rate : 0.2808988690376282
# numAdv : 24
# queries : 10859
# i: 26
# success_rate : 0.21875
# numAdv : 21
# queries : 5189
# i: 27
# success_rate : 0.24731183052062988
# numAdv : 23
# queries : 9389
# i: 28
# success_rate : 0.28723403811454773
# numAdv : 26
# queries : 10289
# i: 29
# success_rate : 0.28125
# numAdv : 27
# queries : 8609
# i: 30
# success_rate : 0.2680412232875824
# numAdv : 25
# queries : 9119
# i: 31
# success_rate : 0.2210526317358017
# numAdv : 21
# queries : 4979
# i: 32
# success_rate : 0.2210526317358017
# numAdv : 21
# queries : 6900
# i: 33
# success_rate : 0.2291666716337204
# numAdv : 22
# queries : 8070
# i: 34
# success_rate : 0.29347825050354004
# numAdv : 26
# queries : 9869
# i: 35
# success_rate : 0.20212766528129578
# numAdv : 19
# queries : 6510
# i: 36
# success_rate : 0.22580644488334656
# numAdv : 20
# queries : 8129
# i: 37
# success_rate : 0.19780220091342926
# numAdv : 18
# queries : 5550
# i: 38
# success_rate : 0.2947368323802948
# numAdv : 27
# queries : 9779
# i: 39
# success_rate : 0.2395833283662796
# numAdv : 22
# queries : 9209
# i: 40
# success_rate : 0.24468085169792175
# numAdv : 23
# queries : 6359
# i: 41
# success_rate : 0.23655913770198822
# numAdv : 21
# queries : 8819
# i: 42
# success_rate : 0.1666666716337204
# numAdv : 16
# queries : 5340
# i: 43
# success_rate : 0.2395833283662796
# numAdv : 22
# queries : 7799
# i: 44
# success_rate : 0.2604166567325592
# numAdv : 24
# queries : 10229
# i: 45
# success_rate : 0.260869562625885
# numAdv : 23
# queries : 5819
# i: 46
# success_rate : 0.28421053290367126
# numAdv : 27
# queries : 9300
# i: 47
# success_rate : 0.18888889253139496
# numAdv : 17
# queries : 5009
# i: 48
# success_rate : 0.2222222238779068
# numAdv : 22
# queries : 7260
# i: 49
# success_rate : 0.36263737082481384
# numAdv : 33
# queries : 11850
# i: 50
# success_rate : 0.22448979318141937
# numAdv : 21
# queries : 6029
# i: 51
# success_rate : 0.3404255211353302
# numAdv : 31
# queries : 9839
# i: 52
# success_rate : 0.19354838132858276
# numAdv : 17
# queries : 6389
# i: 53
# success_rate : 0.2526315748691559
# numAdv : 23
# queries : 9449
# i: 54
# success_rate : 0.260869562625885
# numAdv : 23
# queries : 7139
# i: 55
# success_rate : 0.28421053290367126
# numAdv : 27
# queries : 9930
# i: 56
# success_rate : 0.28421053290367126
# numAdv : 27
# queries : 10139
# i: 57
# success_rate : 0.27659574151039124
# numAdv : 25
# queries : 7679
# i: 58
# success_rate : 0.23076923191547394
# numAdv : 21
# queries : 6840
# i: 59
# success_rate : 0.2680412232875824
# numAdv : 25
# queries : 9689
# i: 60
# success_rate : 0.23863635957241058
# numAdv : 20
# queries : 7320
# i: 61
# success_rate : 0.3297872245311737
# numAdv : 30
# queries : 7769
# i: 62
# success_rate : 0.2604166567325592
# numAdv : 24
# queries : 9929
# i: 63
# success_rate : 0.16161616146564484
# numAdv : 15
# queries : 5159
# i: 64
# success_rate : 0.301075279712677
# numAdv : 28
# queries : 10110
# i: 65
# success_rate : 0.3052631616592407
# numAdv : 29
# queries : 10020
# i: 66
# success_rate : 0.19148936867713928
# numAdv : 18
# queries : 5640
# i: 67
# success_rate : 0.23076923191547394
# numAdv : 21
# queries : 6480
# i: 68
# success_rate : 0.2947368323802948
# numAdv : 27
# queries : 6929
# i: 69
# success_rate : 0.3333333432674408
# numAdv : 32
# queries : 13320
# i: 70
# success_rate : 0.28260868787765503
# numAdv : 25
# queries : 8069
# i: 71
# success_rate : 0.2526315748691559
# numAdv : 23
# queries : 4529
# i: 72
# success_rate : 0.28421053290367126
# numAdv : 27
# queries : 10679
# i: 73
# success_rate : 0.1894736886024475
# numAdv : 18
# queries : 5699
# i: 74
# success_rate : 0.2526315748691559
# numAdv : 23
# queries : 9299
# i: 75
# success_rate : 0.23655913770198822
# numAdv : 21
# queries : 8280
# i: 76
# success_rate : 0.25531914830207825
# numAdv : 23
# queries : 7019
# i: 77
# success_rate : 0.2395833283662796
# numAdv : 22
# queries : 6149
# i: 78
# success_rate : 0.19354838132858276
# numAdv : 17
# queries : 6449
# i: 79
# success_rate : 0.2631579041481018
# numAdv : 25
# queries : 10260
# i: 80
# success_rate : 0.2708333432674408
# numAdv : 26
# queries : 9360
# i: 81
# success_rate : 0.21052631735801697
# numAdv : 20
# queries : 6030
# i: 82
# success_rate : 0.2526315748691559
# numAdv : 23
# queries : 9449
# i: 83
# success_rate : 0.2978723347187042
# numAdv : 27
# queries : 9330
# i: 84
# success_rate : 0.21348313987255096
# numAdv : 18
# queries : 4709
# i: 85
# success_rate : 0.18478260934352875
# numAdv : 17
# queries : 5130
# i: 86
# success_rate : 0.24731183052062988
# numAdv : 23
# queries : 5160
# i: 87
# success_rate : 0.26595744490623474
# numAdv : 24
# queries : 8640
# i: 88
# success_rate : 0.34020617604255676
# numAdv : 32
# queries : 10979
# i: 89
# success_rate : 0.24210526049137115
# numAdv : 22
# queries : 8039
# i: 90
# success_rate : 0.20430107414722443
# numAdv : 18
# queries : 7769
# i: 91
# success_rate : 0.1808510571718216
# numAdv : 16
# queries : 4889
# i: 92
# success_rate : 0.25531914830207825
# numAdv : 23
# queries : 8909
# i: 93
# success_rate : 0.2150537669658661
# numAdv : 20
# queries : 6540
# i: 94
# success_rate : 0.23157894611358643
# numAdv : 21
# queries : 5669
# i: 95
# success_rate : 0.2164948433637619
# numAdv : 20
# queries : 6929
# i: 96
# success_rate : 0.2604166567325592
# numAdv : 24
# queries : 8579
# i: 97
# success_rate : 0.25
# numAdv : 24
# queries : 8790
# i: 98
# success_rate : 0.301075279712677
# numAdv : 28
# queries : 11220
# i: 99
# success_rate : 0.2526315748691559
# numAdv : 23
# queries : 9209
# --------------------------------------------------------------------------------
# Final Success Rate: 0.24835630870036077 | Final Average Queries for Successful Adv Examples: 334
# --------------------------------------------------------------------------------
# fd_eta = 0.001
# i: 0
# success_rate : 0.21739129722118378
# numAdv : 19
# queries : 7829
# i: 1
# success_rate : 0.2527472674846649
# numAdv : 23
# queries : 6660
# i: 2
# success_rate : 0.25773194432258606
# numAdv : 24
# queries : 8189
# i: 3
# success_rate : 0.21052631735801697
# numAdv : 20
# queries : 7980
# i: 4
# success_rate : 0.2947368323802948
# numAdv : 27
# queries : 9719
# i: 5
# success_rate : 0.1855670064687729
# numAdv : 17
# queries : 6749
# i: 6
# success_rate : 0.1666666716337204
# numAdv : 16
# queries : 3420
# i: 7
# success_rate : 0.27173912525177
# numAdv : 24
# queries : 9389
# i: 8
# success_rate : 0.18681319057941437
# numAdv : 17
# queries : 5850
# i: 9
# success_rate : 0.19354838132858276
# numAdv : 17
# queries : 4830
# i: 10
# success_rate : 0.301075279712677
# numAdv : 28
# queries : 10620
# i: 11
# success_rate : 0.20430107414722443
# numAdv : 18
# queries : 7020
# i: 12
# success_rate : 0.20000000298023224
# numAdv : 19
# queries : 5730
# i: 13
# success_rate : 0.20212766528129578
# numAdv : 19
# queries : 5940
# i: 14
# success_rate : 0.1734693944454193
# numAdv : 17
# queries : 7020
# i: 15
# success_rate : 0.20000000298023224
# numAdv : 19
# queries : 6149
# i: 16
# success_rate : 0.2083333283662796
# numAdv : 19
# queries : 5399
# i: 17
# success_rate : 0.19148936867713928
# numAdv : 18
# queries : 5280
# i: 18
# success_rate : 0.21978022158145905
# numAdv : 20
# queries : 6240
# i: 19
# success_rate : 0.2210526317358017
# numAdv : 21
# queries : 7499
# i: 20
# success_rate : 0.2967033088207245
# numAdv : 27
# queries : 7950
# i: 21
# success_rate : 0.2395833283662796
# numAdv : 22
# queries : 9809
# i: 22
# success_rate : 0.23595505952835083
# numAdv : 21
# queries : 7830
# i: 23
# success_rate : 0.1595744639635086
# numAdv : 14
# queries : 7139
# i: 24
# success_rate : 0.3020833432674408
# numAdv : 29
# queries : 11250
# i: 25
# success_rate : 0.32967033982276917
# numAdv : 30
# queries : 12330
# i: 26
# success_rate : 0.2680412232875824
# numAdv : 25
# queries : 7799
# i: 27
# success_rate : 0.21739129722118378
# numAdv : 19
# queries : 7739
# i: 28
# success_rate : 0.23655913770198822
# numAdv : 21
# queries : 7319
# i: 29
# success_rate : 0.28421053290367126
# numAdv : 27
# queries : 10380
# i: 30
# success_rate : 0.2604166567325592
# numAdv : 24
# queries : 8099
# i: 31
# success_rate : 0.2291666716337204
# numAdv : 22
# queries : 6870
# i: 32
# success_rate : 0.17894737422466278
# numAdv : 17
# queries : 6900
# i: 33
# success_rate : 0.21875
# numAdv : 21
# queries : 6329
# i: 34
# success_rate : 0.27173912525177
# numAdv : 24
# queries : 8339
# i: 35
# success_rate : 0.21052631735801697
# numAdv : 20
# queries : 5730
# i: 36
# success_rate : 0.24731183052062988
# numAdv : 23
# queries : 6000
# i: 37
# success_rate : 0.14772726595401764
# numAdv : 12
# queries : 3599
# i: 38
# success_rate : 0.27368420362472534
# numAdv : 25
# queries : 6990
# i: 39
# success_rate : 0.2395833283662796
# numAdv : 22
# queries : 9389
# i: 40
# success_rate : 0.2526315748691559
# numAdv : 23
# queries : 7799
# i: 41
# success_rate : 0.20652173459529877
# numAdv : 18
# queries : 6779
# i: 42
# success_rate : 0.1770833283662796
# numAdv : 16
# queries : 6389
# i: 43
# success_rate : 0.2291666716337204
# numAdv : 22
# queries : 5909
# i: 44
# success_rate : 0.1473684161901474
# numAdv : 13
# queries : 4289
# i: 45
# success_rate : 0.31578946113586426
# numAdv : 29
# queries : 9749
# i: 46
# success_rate : 0.27659574151039124
# numAdv : 25
# queries : 8459
# i: 47
# success_rate : 0.20652173459529877
# numAdv : 18
# queries : 4019
# i: 48
# success_rate : 0.2525252401828766
# numAdv : 24
# queries : 9029
# i: 49
# success_rate : 0.34065935015678406
# numAdv : 31
# queries : 10380
# i: 50
# success_rate : 0.2142857164144516
# numAdv : 21
# queries : 6360
# i: 51
# success_rate : 0.27368420362472534
# numAdv : 25
# queries : 7019
# i: 52
# success_rate : 0.20212766528129578
# numAdv : 19
# queries : 6750
# i: 53
# success_rate : 0.1770833283662796
# numAdv : 16
# queries : 4889
# i: 54
# success_rate : 0.19354838132858276
# numAdv : 17
# queries : 3839
# i: 55
# success_rate : 0.27835050225257874
# numAdv : 26
# queries : 10259
# i: 56
# success_rate : 0.23404255509376526
# numAdv : 22
# queries : 9059
# i: 57
# success_rate : 0.27368420362472534
# numAdv : 25
# queries : 7890
# i: 58
# success_rate : 0.25
# numAdv : 23
# queries : 6690
# i: 59
# success_rate : 0.24742268025875092
# numAdv : 23
# queries : 7229
# i: 60
# success_rate : 0.25555557012557983
# numAdv : 23
# queries : 9330
# i: 61
# success_rate : 0.301075279712677
# numAdv : 28
# queries : 7230
# i: 62
# success_rate : 0.2395833283662796
# numAdv : 22
# queries : 8370
# i: 63
# success_rate : 0.1818181872367859
# numAdv : 18
# queries : 6180
# i: 64
# success_rate : 0.24731183052062988
# numAdv : 23
# queries : 5340
# i: 65
# success_rate : 0.27368420362472534
# numAdv : 25
# queries : 7829
# i: 66
# success_rate : 0.16842105984687805
# numAdv : 16
# queries : 3840
# i: 67
# success_rate : 0.19780220091342926
# numAdv : 18
# queries : 4860
# i: 68
# success_rate : 0.28723403811454773
# numAdv : 26
# queries : 9030
# i: 69
# success_rate : 0.3020833432674408
# numAdv : 29
# queries : 12180
# i: 70
# success_rate : 0.2795698940753937
# numAdv : 26
# queries : 8310
# i: 71
# success_rate : 0.2857142984867096
# numAdv : 28
# queries : 5520
# i: 72
# success_rate : 0.25531914830207825
# numAdv : 23
# queries : 9449
# i: 73
# success_rate : 0.1894736886024475
# numAdv : 18
# queries : 5940
# i: 74
# success_rate : 0.25531914830207825
# numAdv : 23
# queries : 10769
# i: 75
# success_rate : 0.22580644488334656
# numAdv : 20
# queries : 7379
# i: 76
# success_rate : 0.25531914830207825
# numAdv : 23
# queries : 7709
# i: 77
# success_rate : 0.25773194432258606
# numAdv : 24
# queries : 8009
# i: 78
# success_rate : 0.1894736886024475
# numAdv : 18
# queries : 6810
# i: 79
# success_rate : 0.25531914830207825
# numAdv : 23
# queries : 6749
# i: 80
# success_rate : 0.1979166716337204
# numAdv : 19
# queries : 6300
# i: 81
# success_rate : 0.2291666716337204
# numAdv : 22
# queries : 9240
# i: 82
# success_rate : 0.24468085169792175
# numAdv : 23
# queries : 7739
# i: 83
# success_rate : 0.3052631616592407
# numAdv : 29
# queries : 10140
# i: 84
# success_rate : 0.20224718749523163
# numAdv : 17
# queries : 3990
# i: 85
# success_rate : 0.16304348409175873
# numAdv : 15
# queries : 5400
# i: 86
# success_rate : 0.28421053290367126
# numAdv : 27
# queries : 8789
# i: 87
# success_rate : 0.20212766528129578
# numAdv : 19
# queries : 6300
# i: 88
# success_rate : 0.25
# numAdv : 24
# queries : 8190
# i: 89
# success_rate : 0.2526315748691559
# numAdv : 23
# queries : 7799
# i: 90
# success_rate : 0.1354166716337204
# numAdv : 13
# queries : 4410
# i: 91
# success_rate : 0.20212766528129578
# numAdv : 19
# queries : 5970
# i: 92
# success_rate : 0.25
# numAdv : 23
# queries : 8340
# i: 93
# success_rate : 0.2688172161579132
# numAdv : 25
# queries : 9150
# i: 94
# success_rate : 0.2708333432674408
# numAdv : 26
# queries : 8580
# i: 95
# success_rate : 0.2886597812175751
# numAdv : 27
# queries : 8579
# i: 96
# success_rate : 0.22448979318141937
# numAdv : 21
# queries : 7770
# i: 97
# success_rate : 0.2395833283662796
# numAdv : 22
# queries : 9029
# i: 98
# success_rate : 0.23076923191547394
# numAdv : 21
# queries : 8370
# i: 99
# success_rate : 0.21052631735801697
# numAdv : 20
# queries : 6150
# --------------------------------------------------------------------------------
# Final Success Rate: 0.23510705967916884 | Final Average Queries for Successful Adv Examples: 333
# --------------------------------------------------------------------------------

# %%
print('defence with RND_coefficient = 0.02 :')

with torch.no_grad():
    # Launch the attack using the NES class and its generate method
    #############################
    # Your code goes here
    nes = NES(model_to_fool = model, dataset_size = dataset_size, args = args, device = device, RND_coefficient=0.02)
    model.eval()
    for fd_eta in [0.01, 0.001]:
      print(f'fd_eta = {fd_eta}')
      args['fd_eta'] = fd_eta
      _ = nes.generate()

    #############################
# Out:
# defence with RND_coefficient = 0.02 :
# fd_eta = 0.01
# i: 0
# success_rate : 0.3655914068222046
# numAdv : 34
# queries : 12840
# i: 1
# success_rate : 0.3181818127632141
# numAdv : 27
# queries : 8640
# i: 2
# success_rate : 0.31182795763015747
# numAdv : 29
# queries : 8730
# i: 3
# success_rate : 0.31182795763015747
# numAdv : 29
# queries : 9359
# i: 4
# success_rate : 0.3186813294887543
# numAdv : 29
# queries : 7590
# i: 5
# success_rate : 0.2395833283662796
# numAdv : 22
# queries : 7109
# i: 6
# success_rate : 0.35483869910240173
# numAdv : 32
# queries : 11309
# i: 7
# success_rate : 0.3222222328186035
# numAdv : 29
# queries : 8250
# i: 8
# success_rate : 0.31460675597190857
# numAdv : 28
# queries : 10560
# i: 9
# success_rate : 0.26966291666030884
# numAdv : 23
# queries : 8519
# i: 10
# success_rate : 0.3186813294887543
# numAdv : 29
# queries : 8730
# i: 11
# success_rate : 0.32608696818351746
# numAdv : 30
# queries : 7410
# i: 12
# success_rate : 0.2527472674846649
# numAdv : 23
# queries : 5010
# i: 13
# success_rate : 0.20879121124744415
# numAdv : 19
# queries : 4620
# i: 14
# success_rate : 0.27272728085517883
# numAdv : 27
# queries : 8340
# i: 15
# success_rate : 0.3297872245311737
# numAdv : 30
# queries : 12510
# i: 16
# success_rate : 0.25806450843811035
# numAdv : 23
# queries : 7889
# i: 17
# success_rate : 0.2978723347187042
# numAdv : 27
# queries : 10199
# i: 18
# success_rate : 0.30337077379226685
# numAdv : 26
# queries : 9269
# i: 19
# success_rate : 0.3695652186870575
# numAdv : 34
# queries : 13770
# i: 20
# success_rate : 0.40697672963142395
# numAdv : 34
# queries : 10800
# i: 21
# success_rate : 0.3263157904148102
# numAdv : 31
# queries : 9149
# i: 22
# success_rate : 0.3222222328186035
# numAdv : 29
# queries : 8129
# i: 23
# success_rate : 0.27173912525177
# numAdv : 24
# queries : 9539
# i: 24
# success_rate : 0.3586956560611725
# numAdv : 33
# queries : 8999
# i: 25
# success_rate : 0.41111111640930176
# numAdv : 37
# queries : 12359
# i: 26
# success_rate : 0.32258063554763794
# numAdv : 29
# queries : 9869
# i: 27
# success_rate : 0.3333333432674408
# numAdv : 31
# queries : 9180
# i: 28
# success_rate : 0.3222222328186035
# numAdv : 29
# queries : 8549
# i: 29
# success_rate : 0.33707866072654724
# numAdv : 30
# queries : 10260
# i: 30
# success_rate : 0.29032257199287415
# numAdv : 26
# queries : 7950
# i: 30
# success_rate : 0.29032257199287415
# numAdv : 26
# queries : 7950
# i: 31
# success_rate : 0.2777777910232544
# numAdv : 25
# queries : 8580
# i: 31
# success_rate : 0.2777777910232544
# numAdv : 25
# queries : 8580
# i: 32
# success_rate : 0.30434781312942505
# numAdv : 27
# queries : 10349
# i: 32
# success_rate : 0.30434781312942505
# numAdv : 27
# queries : 10349
# i: 33
# success_rate : 0.28125
# numAdv : 27
# queries : 6900
# i: 33
# success_rate : 0.28125
# numAdv : 27
# queries : 6900
# i: 34
# success_rate : 0.3563218414783478
# numAdv : 31
# queries : 9959
# i: 34
# success_rate : 0.3563218414783478
# numAdv : 31
# queries : 9959
# i: 35
# success_rate : 0.27173912525177
# numAdv : 24
# queries : 8580
# i: 35
# success_rate : 0.27173912525177
# numAdv : 24
# queries : 8580
# i: 36
# success_rate : 0.33695653080940247
# numAdv : 31
# queries : 8670
# i: 36
# success_rate : 0.33695653080940247
# numAdv : 31
# queries : 8670
# i: 37
# success_rate : 0.25581395626068115
# numAdv : 22
# queries : 7889
# i: 37
# success_rate : 0.25581395626068115
# numAdv : 22
# queries : 7889
# i: 38
# success_rate : 0.3695652186870575
# numAdv : 34
# queries : 12059
# i: 38
# success_rate : 0.3695652186870575
# numAdv : 34
# queries : 12059
# i: 39
# success_rate : 0.31111112236976624
# numAdv : 28
# queries : 9750
# i: 39
# success_rate : 0.31111112236976624
# numAdv : 28
# queries : 9750
# i: 40
# success_rate : 0.3333333432674408
# numAdv : 30
# queries : 9480
# i: 40
# success_rate : 0.3333333432674408
# numAdv : 30
# queries : 9480
# i: 41
# success_rate : 0.2967033088207245
# numAdv : 27
# queries : 7770
# i: 41
# success_rate : 0.2967033088207245
# numAdv : 27
# queries : 7770
# i: 42
# success_rate : 0.2631579041481018
# numAdv : 25
# queries : 9540
# i: 42
# success_rate : 0.2631579041481018
# numAdv : 25
# queries : 9540
# i: 43
# success_rate : 0.260869562625885
# numAdv : 23
# queries : 5879
# i: 43
# success_rate : 0.260869562625885
# numAdv : 23
# queries : 5879
# i: 44
# success_rate : 0.29032257199287415
# numAdv : 26
# queries : 10049
# i: 44
# success_rate : 0.29032257199287415
# numAdv : 26
# queries : 10049
# i: 45
# success_rate : 0.35227271914482117
# numAdv : 30
# queries : 9989
# i: 45
# success_rate : 0.35227271914482117
# numAdv : 30
# queries : 9989
# i: 46
# success_rate : 0.34065935015678406
# numAdv : 31
# queries : 7320
# i: 46
# success_rate : 0.34065935015678406
# numAdv : 31
# queries : 7320
# i: 47
# success_rate : 0.27906978130340576
# numAdv : 24
# queries : 8880
# i: 47
# success_rate : 0.27906978130340576
# numAdv : 24
# queries : 8880
# i: 48
# success_rate : 0.26595744490623474
# numAdv : 24
# queries : 8490
# i: 48
# success_rate : 0.26595744490623474
# numAdv : 24
# queries : 8490
# i: 49
# success_rate : 0.40229883790016174
# numAdv : 34
# queries : 11039
# i: 49
# success_rate : 0.40229883790016174
# numAdv : 34
# queries : 11039
# i: 50
# success_rate : 0.3404255211353302
# numAdv : 31
# queries : 10769
# i: 50
# success_rate : 0.3404255211353302
# numAdv : 31
# queries : 10769
# i: 51
# success_rate : 0.3483146131038666
# numAdv : 31
# queries : 9300
# i: 51
# success_rate : 0.3483146131038666
# numAdv : 31
# queries : 9300
# i: 52
# success_rate : 0.30434781312942505
# numAdv : 27
# queries : 8159
# i: 52
# success_rate : 0.30434781312942505
# numAdv : 27
# queries : 8159
# i: 53
# success_rate : 0.3076923191547394
# numAdv : 28
# queries : 10260
# i: 53
# success_rate : 0.3076923191547394
# numAdv : 28
# queries : 10260
# i: 54
# success_rate : 0.28260868787765503
# numAdv : 25
# queries : 7049
# i: 54
# success_rate : 0.28260868787765503
# numAdv : 25
# queries : 7049
# i: 55
# success_rate : 0.32608696818351746
# numAdv : 30
# queries : 10590
# i: 55
# success_rate : 0.32608696818351746
# numAdv : 30
# queries : 10590
# i: 56
# success_rate : 0.3076923191547394
# numAdv : 28
# queries : 10110
# i: 56
# success_rate : 0.3076923191547394
# numAdv : 28
# queries : 10110
# i: 57
# success_rate : 0.2808988690376282
# numAdv : 24
# queries : 8519
# i: 57
# success_rate : 0.2808988690376282
# numAdv : 24
# queries : 8519
# i: 58
# success_rate : 0.3258427083492279
# numAdv : 29
# queries : 8969
# i: 58
# success_rate : 0.3258427083492279
# numAdv : 29
# queries : 8969
# i: 59
# success_rate : 0.3186813294887543
# numAdv : 29
# queries : 11430
# i: 59
# success_rate : 0.3186813294887543
# numAdv : 29
# queries : 11430
# i: 60
# success_rate : 0.28735631704330444
# numAdv : 24
# queries : 5729
# i: 60
# success_rate : 0.28735631704330444
# numAdv : 24
# queries : 5729
# i: 61
# success_rate : 0.3483146131038666
# numAdv : 31
# queries : 7949
# i: 61
# success_rate : 0.3483146131038666
# numAdv : 31
# queries : 7949
# i: 62
# success_rate : 0.33695653080940247
# numAdv : 31
# queries : 11940
# i: 62
# success_rate : 0.33695653080940247
# numAdv : 31
# queries : 11940
# i: 63
# success_rate : 0.27835050225257874
# numAdv : 26
# queries : 7829
# i: 63
# success_rate : 0.27835050225257874
# numAdv : 26
# queries : 7829
# i: 64
# success_rate : 0.33707866072654724
# numAdv : 30
# queries : 8460
# i: 64
# success_rate : 0.33707866072654724
# numAdv : 30
# queries : 8460
# i: 65
# success_rate : 0.32967033982276917
# numAdv : 30
# queries : 8970
# i: 65
# success_rate : 0.32967033982276917
# numAdv : 30
# queries : 8970
# i: 66
# success_rate : 0.23076923191547394
# numAdv : 21
# queries : 8339
# i: 66
# success_rate : 0.23076923191547394
# numAdv : 21
# queries : 8339
# i: 67
# success_rate : 0.30000001192092896
# numAdv : 27
# queries : 9240
# i: 67
# success_rate : 0.30000001192092896
# numAdv : 27
# queries : 9240
# i: 68
# success_rate : 0.3295454680919647
# numAdv : 29
# queries : 7350
# i: 68
# success_rate : 0.3295454680919647
# numAdv : 29
# queries : 7350
# i: 69
# success_rate : 0.3978494703769684
# numAdv : 37
# queries : 11579
# i: 69
# success_rate : 0.3978494703769684
# numAdv : 37
# queries : 11579
# i: 70
# success_rate : 0.2954545319080353
# numAdv : 25
# queries : 6689
# i: 70
# success_rate : 0.2954545319080353
# numAdv : 25
# queries : 6689
# i: 71
# success_rate : 0.3333333432674408
# numAdv : 31
# queries : 7140
# i: 71
# success_rate : 0.3333333432674408
# numAdv : 31
# queries : 7140
# i: 72
# success_rate : 0.3444444537162781
# numAdv : 31
# queries : 11220
# i: 72
# success_rate : 0.3444444537162781
# numAdv : 31
# queries : 11220
# i: 73
# success_rate : 0.239130437374115
# numAdv : 22
# queries : 8490
# i: 73
# success_rate : 0.239130437374115
# numAdv : 22
# queries : 8490
# i: 74
# success_rate : 0.38297873735427856
# numAdv : 36
# queries : 11550
# i: 74
# success_rate : 0.38297873735427856
# numAdv : 36
# queries : 11550
# i: 75
# success_rate : 0.27173912525177
# numAdv : 24
# queries : 8130
# i: 75
# success_rate : 0.27173912525177
# numAdv : 24
# queries : 8130
# i: 76
# success_rate : 0.3483146131038666
# numAdv : 31
# queries : 10350
# i: 76
# success_rate : 0.3483146131038666
# numAdv : 31
# queries : 10350
# i: 77
# success_rate : 0.29032257199287415
# numAdv : 26
# queries : 6779
# i: 77
# success_rate : 0.29032257199287415
# numAdv : 26
# queries : 6779
# i: 78
# success_rate : 0.23076923191547394
# numAdv : 21
# queries : 7530
# i: 78
# success_rate : 0.23076923191547394
# numAdv : 21
# queries : 7530
# i: 79
# success_rate : 0.31578946113586426
# numAdv : 29
# queries : 7469
# i: 79
# success_rate : 0.31578946113586426
# numAdv : 29
# queries : 7469
# i: 80
# success_rate : 0.3020833432674408
# numAdv : 29
# queries : 8489
# i: 80
# success_rate : 0.3020833432674408
# numAdv : 29
# queries : 8489
# i: 81
# success_rate : 0.2947368323802948
# numAdv : 27
# queries : 9029
# i: 81
# success_rate : 0.2947368323802948
# numAdv : 27
# queries : 9029
# i: 82
# success_rate : 0.3404255211353302
# numAdv : 31
# queries : 10799
# i: 82
# success_rate : 0.3404255211353302
# numAdv : 31
# queries : 10799
# i: 83
# success_rate : 0.40425533056259155
# numAdv : 38
# queries : 9360
# i: 83
# success_rate : 0.40425533056259155
# numAdv : 38
# queries : 9360
# i: 84
# success_rate : 0.2666666805744171
# numAdv : 24
# queries : 6600
# i: 84
# success_rate : 0.2666666805744171
# numAdv : 24
# queries : 6600
# i: 85
# success_rate : 0.2688172161579132
# numAdv : 25
# queries : 7890
# i: 85
# success_rate : 0.2688172161579132
# numAdv : 25
# queries : 7890
# i: 86
# success_rate : 0.3258427083492279
# numAdv : 29
# queries : 7679
# i: 86
# success_rate : 0.3258427083492279
# numAdv : 29
# queries : 7679
# i: 87
# success_rate : 0.33695653080940247
# numAdv : 31
# queries : 12090
# i: 87
# success_rate : 0.33695653080940247
# numAdv : 31
# queries : 12090
# i: 88
# success_rate : 0.3695652186870575
# numAdv : 34
# queries : 10589
# i: 88
# success_rate : 0.3695652186870575
# numAdv : 34
# queries : 10589
# i: 89
# success_rate : 0.32258063554763794
# numAdv : 29
# queries : 10289
# i: 89
# success_rate : 0.32258063554763794
# numAdv : 29
# queries : 10289
# i: 90
# success_rate : 0.2688172161579132
# numAdv : 25
# queries : 7560
# i: 90
# success_rate : 0.2688172161579132
# numAdv : 25
# queries : 7560
# i: 91
# success_rate : 0.23404255509376526
# numAdv : 22
# queries : 5580
# i: 91
# success_rate : 0.23404255509376526
# numAdv : 22
# queries : 5580
# i: 92
# success_rate : 0.3068181872367859
# numAdv : 27
# queries : 9000
# i: 92
# success_rate : 0.3068181872367859
# numAdv : 27
# queries : 9000
# i: 93
# success_rate : 0.25
# numAdv : 22
# queries : 9779
# i: 93
# success_rate : 0.25
# numAdv : 22
# queries : 9779
# i: 94
# success_rate : 0.2888889014720917
# numAdv : 26
# queries : 7770
# i: 94
# success_rate : 0.2888889014720917
# numAdv : 26
# queries : 7770
# i: 95
# success_rate : 0.28421053290367126
# numAdv : 27
# queries : 8730
# i: 95
# success_rate : 0.28421053290367126
# numAdv : 27
# queries : 8730
# i: 96
# success_rate : 0.3020833432674408
# numAdv : 29
# queries : 7679
# i: 96
# success_rate : 0.3020833432674408
# numAdv : 29
# queries : 7679
# i: 97
# success_rate : 0.35789474844932556
# numAdv : 34
# queries : 11340
# i: 97
# success_rate : 0.35789474844932556
# numAdv : 34
# queries : 11340
# i: 98
# success_rate : 0.34736841917037964
# numAdv : 32
# queries : 10259
# i: 98
# success_rate : 0.34736841917037964
# numAdv : 32
# queries : 10259
# i: 99
# success_rate : 0.31182795763015747
# numAdv : 29
# queries : 9270
# --------------------------------------------------------------------------------
# Final Success Rate: 0.31156492564105903 | Final Average Queries for Successful Adv Examples: 316
# --------------------------------------------------------------------------------
# fd_eta = 0.001
# i: 99
# success_rate : 0.31182795763015747
# numAdv : 29
# queries : 9270
# --------------------------------------------------------------------------------
# Final Success Rate: 0.31156492564105903 | Final Average Queries for Successful Adv Examples: 316
# --------------------------------------------------------------------------------
# fd_eta = 0.001
# i: 0
# success_rate : 0.37634408473968506
# numAdv : 34
# queries : 12299
# i: 0
# success_rate : 0.37634408473968506
# numAdv : 34
# queries : 12299
# i: 1
# success_rate : 0.3333333432674408
# numAdv : 30
# queries : 6240
# i: 1
# success_rate : 0.3333333432674408
# numAdv : 30
# queries : 6240
# i: 2
# success_rate : 0.30434781312942505
# numAdv : 27
# queries : 8189
# i: 2
# success_rate : 0.30434781312942505
# numAdv : 27
# queries : 8189
# i: 3
# success_rate : 0.378947377204895
# numAdv : 36
# queries : 12029
# i: 3
# success_rate : 0.378947377204895
# numAdv : 36
# queries : 12029
# i: 4
# success_rate : 0.3076923191547394
# numAdv : 28
# queries : 8010
# i: 4
# success_rate : 0.3076923191547394
# numAdv : 28
# queries : 8010
# i: 5
# success_rate : 0.22340425848960876
# numAdv : 21
# queries : 6749
# i: 5
# success_rate : 0.22340425848960876
# numAdv : 21
# queries : 6749
# i: 6
# success_rate : 0.260869562625885
# numAdv : 23
# queries : 8519
# i: 6
# success_rate : 0.260869562625885
# numAdv : 23
# queries : 8519
# i: 7
# success_rate : 0.3186813294887543
# numAdv : 29
# queries : 6900
# i: 7
# success_rate : 0.3186813294887543
# numAdv : 29
# queries : 6900
# i: 8
# success_rate : 0.35555556416511536
# numAdv : 32
# queries : 11100
# i: 8
# success_rate : 0.35555556416511536
# numAdv : 32
# queries : 11100
# i: 9
# success_rate : 0.25806450843811035
# numAdv : 23
# queries : 5399
# i: 9
# success_rate : 0.25806450843811035
# numAdv : 23
# queries : 5399
# i: 10
# success_rate : 0.32608696818351746
# numAdv : 30
# queries : 6060
# i: 10
# success_rate : 0.32608696818351746
# numAdv : 30
# queries : 6060
# i: 11
# success_rate : 0.2747252881526947
# numAdv : 25
# queries : 7260
# i: 11
# success_rate : 0.2747252881526947
# numAdv : 25
# queries : 7260
# i: 12
# success_rate : 0.24719101190567017
# numAdv : 22
# queries : 8940
# i: 12
# success_rate : 0.24719101190567017
# numAdv : 22
# queries : 8940
# i: 13
# success_rate : 0.26595744490623474
# numAdv : 24
# queries : 6780
# i: 13
# success_rate : 0.26595744490623474
# numAdv : 24
# queries : 6780
# i: 14
# success_rate : 0.2886597812175751
# numAdv : 27
# queries : 11039
# i: 14
# success_rate : 0.2886597812175751
# numAdv : 27
# queries : 11039
# i: 15
# success_rate : 0.3085106313228607
# numAdv : 28
# queries : 11369
# i: 15
# success_rate : 0.3085106313228607
# numAdv : 28
# queries : 11369
# i: 16
# success_rate : 0.23404255509376526
# numAdv : 22
# queries : 5819
# i: 16
# success_rate : 0.23404255509376526
# numAdv : 22
# queries : 5819
# i: 17
# success_rate : 0.25806450843811035
# numAdv : 23
# queries : 6749
# i: 17
# success_rate : 0.25806450843811035
# numAdv : 23
# queries : 6749
# i: 18
# success_rate : 0.31111112236976624
# numAdv : 28
# queries : 9600
# i: 18
# success_rate : 0.31111112236976624
# numAdv : 28
# queries : 9600
# i: 19
# success_rate : 0.3695652186870575
# numAdv : 34
# queries : 12840
# i: 19
# success_rate : 0.3695652186870575
# numAdv : 34
# queries : 12840
# i: 20
# success_rate : 0.3604651093482971
# numAdv : 30
# queries : 7889
# i: 20
# success_rate : 0.3604651093482971
# numAdv : 30
# queries : 7889
# i: 21
# success_rate : 0.25806450843811035
# numAdv : 23
# queries : 6779
# i: 21
# success_rate : 0.25806450843811035
# numAdv : 23
# queries : 6779
# i: 22
# success_rate : 0.2954545319080353
# numAdv : 25
# queries : 6929
# i: 22
# success_rate : 0.2954545319080353
# numAdv : 25
# queries : 6929
# i: 23
# success_rate : 0.20430107414722443
# numAdv : 18
# queries : 4979
# i: 23
# success_rate : 0.20430107414722443
# numAdv : 18
# queries : 4979
# i: 24
# success_rate : 0.3510638177394867
# numAdv : 32
# queries : 11999
# i: 24
# success_rate : 0.3510638177394867
# numAdv : 32
# queries : 11999
# i: 25
# success_rate : 0.3139534890651703
# numAdv : 27
# queries : 10020
# i: 25
# success_rate : 0.3139534890651703
# numAdv : 27
# queries : 10020
# i: 26
# success_rate : 0.35789474844932556
# numAdv : 34
# queries : 11370
# i: 26
# success_rate : 0.35789474844932556
# numAdv : 34
# queries : 11370
# i: 27
# success_rate : 0.31182795763015747
# numAdv : 29
# queries : 9300
# i: 27
# success_rate : 0.31182795763015747
# numAdv : 29
# queries : 9300

# %%
print('defence with RND_coefficient = 0.02 :')

with torch.no_grad():
    # Launch the attack using the NES class and its generate method
    #############################
    # Your code goes here
    model.eval()
    for fd_eta in [0.001]:
      print(f'fd_eta = {fd_eta}')
      args['fd_eta'] =fd_eta
      NES(model_to_fool = model, dataset_size = dataset_size, args = args, device = device, RND_coefficient=0.02).generate()

    #############################
# Out:
# defence with RND_coefficient = 0.02 :
# fd_eta = 0.001
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# i: 0
# success_rate : 0.35483869910240173
# numAdv : 32
# queries : 11400
# i: 1
# success_rate : 0.3444444537162781
# numAdv : 31
# queries : 10590
# i: 2
# success_rate : 0.301075279712677
# numAdv : 28
# queries : 8670
# i: 3
# success_rate : 0.2777777910232544
# numAdv : 25
# queries : 8010
# i: 4
# success_rate : 0.3586956560611725
# numAdv : 33
# queries : 7710
# i: 5
# success_rate : 0.20000000298023224
# numAdv : 19
# queries : 5400
# i: 6
# success_rate : 0.30434781312942505
# numAdv : 27
# queries : 10349
# i: 7
# success_rate : 0.2888889014720917
# numAdv : 26
# queries : 5820
# i: 8
# success_rate : 0.2888889014720917
# numAdv : 26
# queries : 8370
# i: 9
# success_rate : 0.19540229439735413
# numAdv : 16
# queries : 5220
# i: 10
# success_rate : 0.3181818127632141
# numAdv : 27
# queries : 10110
# i: 11
# success_rate : 0.30434781312942505
# numAdv : 27
# queries : 9149
# i: 12
# success_rate : 0.260869562625885
# numAdv : 23
# queries : 7889
# i: 13
# success_rate : 0.24731183052062988
# numAdv : 23
# queries : 5970
# i: 14
# success_rate : 0.2857142984867096
# numAdv : 28
# queries : 10800
# i: 15
# success_rate : 0.3723404109477997
# numAdv : 34
# queries : 12419
# i: 16
# success_rate : 0.24175824224948883
# numAdv : 22
# queries : 6930
# i: 17
# success_rate : 0.2631579041481018
# numAdv : 25
# queries : 6960
# i: 18
# success_rate : 0.2666666805744171
# numAdv : 24
# queries : 5820
# i: 19
# success_rate : 0.3186813294887543
# numAdv : 29
# queries : 11010
# i: 20
# success_rate : 0.3604651093482971
# numAdv : 30
# queries : 7469
# i: 21
# success_rate : 0.32258063554763794
# numAdv : 29
# queries : 8249
# i: 22
# success_rate : 0.3222222328186035
# numAdv : 29
# queries : 8310
# i: 23
# success_rate : 0.22580644488334656
# numAdv : 20
# queries : 6719
# i: 24
# success_rate : 0.37362638115882874
# numAdv : 34
# queries : 11430
# i: 25
# success_rate : 0.40909090638160706
# numAdv : 35
# queries : 11730
# i: 26
# success_rate : 0.34375
# numAdv : 33
# queries : 11850
# i: 27
# success_rate : 0.2888889014720917
# numAdv : 26
# queries : 9510
# i: 28
# success_rate : 0.3076923191547394
# numAdv : 28
# queries : 6870
# i: 29
# success_rate : 0.35164836049079895
# numAdv : 32
# queries : 10860
# i: 30
# success_rate : 0.3076923191547394
# numAdv : 28
# queries : 8040
# i: 31
# success_rate : 0.23333333432674408
# numAdv : 21
# queries : 6659
# i: 32
# success_rate : 0.29347825050354004
# numAdv : 26
# queries : 9389
# i: 33
# success_rate : 0.3505154550075531
# numAdv : 33
# queries : 10950
# i: 34
# success_rate : 0.35555556416511536
# numAdv : 32
# queries : 9780
# i: 35
# success_rate : 0.24444444477558136
# numAdv : 22
# queries : 8069
# i: 36
# success_rate : 0.29032257199287415
# numAdv : 26
# queries : 7859
# i: 37
# success_rate : 0.23863635957241058
# numAdv : 20
# queries : 4949
# i: 38
# success_rate : 0.31111112236976624
# numAdv : 28
# queries : 7260
# i: 39
# success_rate : 0.3297872245311737
# numAdv : 30
# queries : 8609
# i: 40
# success_rate : 0.33695653080940247
# numAdv : 31
# queries : 10170
# i: 41
# success_rate : 0.2795698940753937
# numAdv : 26
# queries : 8520
# i: 42
# success_rate : 0.21875
# numAdv : 21
# queries : 7499
# i: 43
# success_rate : 0.301075279712677
# numAdv : 28
# queries : 10830
# i: 44
# success_rate : 0.3510638177394867
# numAdv : 32
# queries : 14669
# i: 45
# success_rate : 0.35164836049079895
# numAdv : 32
# queries : 9120
# i: 46
# success_rate : 0.3655914068222046
# numAdv : 34
# queries : 9600
# i: 47
# success_rate : 0.28409090638160706
# numAdv : 24
# queries : 7290
# i: 48
# success_rate : 0.2886597812175751
# numAdv : 27
# queries : 9389
# i: 49
# success_rate : 0.4318181872367859
# numAdv : 38
# queries : 10289
# i: 50
# success_rate : 0.2680412232875824
# numAdv : 25
# queries : 6629
# i: 51
# success_rate : 0.3068181872367859
# numAdv : 27
# queries : 7530
# i: 52
# success_rate : 0.2688172161579132
# numAdv : 25
# queries : 7830
# i: 53
# success_rate : 0.239130437374115
# numAdv : 22
# queries : 6239
# i: 54
# success_rate : 0.2183908075094223
# numAdv : 19
# queries : 4139
# i: 55
# success_rate : 0.2967033088207245
# numAdv : 27
# queries : 8100
# i: 56
# success_rate : 0.2637362778186798
# numAdv : 24
# queries : 9000
# i: 57
# success_rate : 0.35555556416511536
# numAdv : 32
# queries : 10050
# i: 58
# success_rate : 0.27272728085517883
# numAdv : 24
# queries : 7890
# i: 59
# success_rate : 0.3333333432674408
# numAdv : 32
# queries : 9180
# i: 60
# success_rate : 0.37078651785850525
# numAdv : 33
# queries : 13170
# i: 61
# success_rate : 0.3483146131038666
# numAdv : 31
# queries : 9029
# i: 62
# success_rate : 0.3404255211353302
# numAdv : 31
# queries : 11369
# i: 63
# success_rate : 0.2680412232875824
# numAdv : 25
# queries : 6719
# i: 64
# success_rate : 0.4021739065647125
# numAdv : 36
# queries : 12060
# i: 65
# success_rate : 0.3258427083492279
# numAdv : 29
# queries : 9210
# i: 66
# success_rate : 0.2222222238779068
# numAdv : 20
# queries : 7350
# i: 67
# success_rate : 0.2183908075094223
# numAdv : 19
# queries : 6059
# i: 68
# success_rate : 0.30000001192092896
# numAdv : 27
# queries : 6870
# i: 69
# success_rate : 0.3804347813129425
# numAdv : 34
# queries : 10439
# i: 70
# success_rate : 0.2888889014720917
# numAdv : 26
# queries : 6720
# i: 71
# success_rate : 0.2857142984867096
# numAdv : 26
# queries : 5220
# i: 72
# success_rate : 0.3870967626571655
# numAdv : 35
# queries : 12479
# i: 73
# success_rate : 0.239130437374115
# numAdv : 22
# queries : 8129
# i: 74
# success_rate : 0.34408602118492126
# numAdv : 31
# queries : 10589
# i: 75
# success_rate : 0.2795698940753937
# numAdv : 26
# queries : 8970
# i: 76
# success_rate : 0.34408602118492126
# numAdv : 31
# queries : 10289
# i: 77
# success_rate : 0.26595744490623474
# numAdv : 24
# queries : 5490
# i: 78
# success_rate : 0.26595744490623474
# numAdv : 24
# queries : 8699
# i: 79
# success_rate : 0.29032257199287415
# numAdv : 26
# queries : 6449
# i: 80
# success_rate : 0.2631579041481018
# numAdv : 25
# queries : 6330
# i: 81
# success_rate : 0.25
# numAdv : 23
# queries : 7920
# i: 82
# success_rate : 0.3404255211353302
# numAdv : 31
# queries : 9569
# i: 83
# success_rate : 0.378947377204895
# numAdv : 36
# queries : 9480
# i: 84
# success_rate : 0.25581395626068115
# numAdv : 22
# queries : 6930
# i: 85
# success_rate : 0.239130437374115
# numAdv : 22
# queries : 6930
# i: 86
# success_rate : 0.30337077379226685
# numAdv : 26
# queries : 8759
# i: 87
# success_rate : 0.28260868787765503
# numAdv : 25
# queries : 6569
# i: 88
# success_rate : 0.36263737082481384
# numAdv : 33
# queries : 10349
# i: 89
# success_rate : 0.31182795763015747
# numAdv : 29
# queries : 9750
# i: 90
# success_rate : 0.28723403811454773
# numAdv : 26
# queries : 9089
# i: 91
# success_rate : 0.24731183052062988
# numAdv : 23
# queries : 6119
# i: 92
# success_rate : 0.2584269642829895
# numAdv : 22
# queries : 5939
# i: 93
# success_rate : 0.29347825050354004
# numAdv : 26
# queries : 7769
# i: 94
# success_rate : 0.32967033982276917
# numAdv : 30
# queries : 9150
# i: 95
# success_rate : 0.31578946113586426
# numAdv : 29
# queries : 8669
# i: 96
# success_rate : 0.2795698940753937
# numAdv : 26
# queries : 7800
# i: 97
# success_rate : 0.29032257199287415
# numAdv : 26
# queries : 8699
# i: 98
# success_rate : 0.38297873735427856
# numAdv : 36
# queries : 10890
# i: 99
# success_rate : 0.2637362778186798
# numAdv : 24
# queries : 7740
# --------------------------------------------------------------------------------
# Final Success Rate: 0.3019505300409617 | Final Average Queries for Successful Adv Examples: 309
# --------------------------------------------------------------------------------

# %%
# Final results report


# without defense, fd_eta=0.01  : Final Success Rate: 0.93 | Final Average Queries for Successful Adv Examples: 264
# without defense, fd_eta=0.001 : Final Success Rate: 0.92 | Final Average Queries for Successful Adv Examples: 267

# defense with RND=0.01, fd_eta=0.01   : Final Success Rate: 0.25 | Final Average Queries for Successful Adv Examples: 334
# defense with RND=0.01, fd_eta=0.001  : Final Success Rate: 0.24 | Final Average Queries for Successful Adv Examples: 333

# defense with RND=0.02, fd_eta=0.01   : Final Success Rate: 0.31 | Final Average Queries for Successful Adv Examples: 316
# defense with RND=0.02, fd_eta=0.001  : Final Success Rate: 0.31 | Final Average Queries for Successful Adv Examples: 309
